# %% [markdown]
# # 求酒店评论相似度并提取相似的评论

# %% [markdown]
# ## 1 导入库和酒店评论数据

# %%
import pandas as pd
import jieba 
data = pd.read_csv("./酒店评论.csv",encoding='gbk',dtype=str)  # 载入全部数据
data = data["评论内容"]
data
# Out:
# 0                                                酒店很适合家庭出行
# 1                                            升级了房间 延迟退房 很赞
# 2        这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...
# 3                                                   酒店很好不错
# 4                                                    超五星好评
#                                ...
# 24775    酒店是老字号宾馆，虽然有装修过但设施比较陈旧房间空调比较小，卫生间里的墙壁有剥落现象，浴室的...
# 24776          本人觉得还好，价格偏高，没有很高档，服务是很好，设施偏老，也不会很大，喜欢楼下的早茶。
# 24777                                         隔音极差，睡眠让人崩溃。
# 24778                                       酒店位置很好，停车场比较小。
# 24779                                     位置好找，停车方便，酒店太老了！
# Name: 评论内容, Length: 24780, dtype: object

# %% [markdown]
# ## 2 求余弦相似度

# %% [markdown]
# ### 2.1 导入gensim模块

# %% [markdown]
# gensim模块用于自然语言处理，使用其中Word2Vec库将每一条评论文本转换为词向量再计算两个词向量之间的余弦相似度，相似度大于（）时为几乎相同的评论。

# %%
import numpy as np
from gensim.models import Word2Vec

model = Word2Vec(data)
w2i = {w: i for i, w in enumerate(model.wv.index_to_key, 1)}
vectors = np.concatenate((np.zeros((1, 100)), model.wv.vectors), axis=0)
w2v = lambda w: vectors[w2i.get(w, 0)]

# %% [markdown]
# ### 2.2 计算$c_m,k=0..N-1$和$c_n,n=k+1..N$的余弦相似度，提取相似的评论

# %%
for k in range(int(13*(len(data)-1)/20),int(14*(len(data)-1)/20)):
    vec1 = np.mean([w2v(w) for w in data[k]], axis=0)
    print("---------"+str(k)+"---------")
    for j in range(k+1,len(data)):
        vec2 = np.mean([w2v(w) for w in data[j]], axis=0)
        if np.linalg.norm(vec1) * np.linalg.norm(vec2) != 0:
            rate = vec1 @ vec2 / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
            if rate > 0.95:
                print("--------------------\n"+data[k]+"\n--------")
                print(data[j]+"\n--------------------")
    print("\n")
# Out:
# ---------16106---------
#
#
# ---------16107---------
#
#
# ---------16108---------
#
#
# ---------16109---------
#
#
# ---------16110---------
# --------------------
# 前台elieen emily 服务好
# --------
# 前台elieen emily melody leo 服务好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# lucky服务好good
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# lucky服务好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Fiona很好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Grace Fiona Tony Sun 前台员工都不吃错
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Grace Fiona Tony sun 前台员工都很好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Grace TOny 前台不错
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Fiona Kevin服务很好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Fiona 服务好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# lucky tomy服务热情
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# lucky grace 服务热情
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Fiona Grace服务态度好 房间好
# --------------------
# --------------------
# 前台elieen emily 服务好
# --------
# Grace Sun 服务好
# --------------------
#
#
# ---------16111---------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# this hotel is a gym, and serious value for your money, a spotless clean room with a very comfortable bed. lovely parks very close by and the tram line is just outside the door if you want to go to the sea side or to look at the zhuhai oprea house on yeli island. i enjoyed my breakfast in the beautiful restaurant, the cleaning lady on the 11th floor goes out of her way to make sure you are happy her name is 刘妈all of the staff are polite and helpful too. ill always stay here when in zhuhai.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Room is spacious, location is great. One thing that disappointed me that my check-in was on 24 Dec, the eve, and we would like to celebrate with friends at Hotel in the night. However, all restaurants or lounges in the hotel or nearby were closed early. Thus, we had to called off the gathering.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Great Hotel! Loved the service and facilities.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Very good
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Overall.... I found out that hotels in Guangzhou even though very near to train or bus station, not encouraged to walk as all the exit points have no escalators or lifts. So if tourist carrying luggages will be hassle, can only call for a taxi.The stay experience in Westin Guangzhou was great and the services is excellent. Our room was upgraded to Executive Rooms with access to the Executive Lounge. We spent most of our time in the hotel after our works as the comfort and hospitality in the lounge were great !
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# very convenient locations for biz Or pleasure
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Near to airport
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# The location is not far from the airport, but there is nothing around the hotel. A couple small stores or small restaurants. No shopping malls or parks. The hotel/apartment has comfortable and spacious rooms, but the cleaning lady entered the room without a knock or warning. It’s like she thought no one was in the room and she wanted to take a break. Very awkward for her and me. Luckily, I had my clothes on. The tv doesn’t not work. My Chinese friend could not get it to work either. The check in was very simple and easy. The shuttle bus to the airport was on time. I’ll definitely stay here again ??????
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Book for a friend hotel is ok
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# stayed at new wing. bed are very comfortable. had a good night sleep after a two weeks trip in China. small mall and MacDonalds next to hotel.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Nice stay
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# lucky服务好good
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Hotel room was nice, location was not that great
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Fiona很好
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Grace FIona 不错
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Grace Fiona Tony Sun 前台员工都不吃错
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Grace Fiona Tony sun 前台员工都很好
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Grace TOny 前台不错
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Fiona Kevin服务很好
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# grace 好厉害，good
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# lucky tomy服务热情
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# lucky grace 服务热情
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Grace Sun 服务好
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Everything good but need to clean outdoor swimming pools
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Nice hotel I liked wanna back again,food was good
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# nice
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Room exact to picture. Really near to all the shopping mall and LRT. Enjoyed my 3 nights here. Toilet abit small to shower though.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Located near the US Embassy. Nice rooms and very helpful staff.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# everytime is an enjoy stay at this HOTEL, very clean easy location and friendly staff.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# nice location close to subway and many facilities and shopping mall
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# very clean HOTEL and close to meny facilities
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Lcy is very good 环境很好。
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# clean room friendly staff and very strategic location
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# great location very clean room friendly and very helpful staff
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# I want to apply for cancellation refund because I did not check in due to the covid19 event. please let me know how can I apply for refund
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Excellent service
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# keumll
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Front desk staff was cheerful. Room is tidy. Room service was efficient but I ordered a noddles the taste not good and a bit cold. Overall is good.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Convenient location, nice stay experienceNo surprise, no disappointed
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# The Hotel was kinda old but the cleanliness was unacceptable. I mean, room was not so ok but breakfast lounge was really dirty, tables, floor, chairs, bars... a disaster regarding cleanliness.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# The hotel provided what you need, but compared to other five stars hotel, I'm not satisfied with staffs friendliness. They don't seems to be eager to host you. The room is big and quite worth for its price. But the service just not making me wanted to go back again.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# Nice swimming pool. Room a little old but still clean. Nearby One Avenue shopping area. Convenient location.
# --------------------
# --------------------
# 前台elieen emily melody leo 服务好
# --------
# very good
# --------------------
# ---------16112---------
#
#
# ---------16113---------
#
#
# ---------16114---------
#
#
# ---------16115---------
# --------------------
# 还行，交通方便
# --------
# 交通方便，
# --------------------
# --------------------
# 还行，交通方便
# --------
# 交通好，出行方便
# --------------------
# --------------------
# 还行，交通方便
# --------
# 还行，交通方便
# --------------------
#
#
# ---------16116---------
#
#
# ---------16117---------
#
#
# ---------16118---------
#
#
# ---------16119---------
#
#
# ---------16120---------
#
#
# ---------16121---------
#
#
# ---------16122---------
#
#
# ---------16123---------
# --------------------
# 早餐还可以
# --------
# 早餐还可以的。
# --------------------
# --------------------
# 早餐还可以
# --------
# 早餐还可以
# --------------------
# --------------------
# 早餐还可以
# --------
# 早餐还可以
# --------------------
# --------------------
# 早餐还可以
# --------
# 早餐还可以
# --------------------
# --------------------
# 早餐还可以
# --------
# 早餐可以的
# --------------------
#
#
# ---------16124---------
#
#
# ---------16125---------
#
#
# ---------16126---------
#
#
# ---------16127---------
# --------------------
# 客户很满意
# --------
# 客户很满意
# --------------------
#
#
# ---------16128---------
#
#
# ---------16129---------
#
#
# ---------16130---------
#
#
# ---------16131---------
#
#
# ---------16132---------
#
#
# ---------16133---------
#
#
# ---------16134---------
#
#
# ---------16135---------
#
#
# ---------16136---------
#
#
# ---------16137---------
#
#
# ---------16138---------
#
#
# ---------16139---------
#
#
# ---------16140---------
#
#
# ---------16141---------
#
#
# ---------16142---------
# --------------------
# 前台经理小朱服务态度很好
# --------
# 前台小朱服务态度很好
# --------------------
#
#
# ---------16143---------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台小姐姐服务态度很好。
# --------------------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 前台小朱服务态度很好
# --------
# 前台服务态度好
# --------------------
#
#
# ---------16144---------
#
#
# ---------16145---------
#
#
# ---------16146---------
#
#
# ---------16147---------
#
#
# ---------16148---------
# --------------------
# 从来都是习惯性的好评，但是这次不得不给个超级差评！预定了酒店带孩子周末玩下，办理了入住的酒店一进门扑鼻而来的是超级发霉的味道！要求换房，换了一个房间之后楼道里是另外一种奇怪的味道！进了房间勉强没有那么大的发霉的味道，带着孩子想下算了，吃了东西回来冲完凉打开冰箱看了下，真的是叫我觉得恶心！冰箱里还有上一个人客人留下的鸭脖子，什么乱七八糟的东西，瞬间再次觉得无语！冲凉的时候用手去拿矿泉水，酒店赠送的，结果瓶子下面是滑滑的，更是叫我觉得心生厌恶！更可笑的是，退房的时候发生的事情！看电视要收费，且前台还说我在威胁她！真的很难以想象一个法律人士在给她讲什么叫强制消费，居然在大庭广众之下说我是在威胁她！真的是对这样的酒店超级无语！国内外五星级酒店住过不少，还真是第一次见到环境这样还态度这样的酒店！
# --------
# “给你一个五星级的家”是**的宣传语，好久没有这么满意的体验了，从酒店前台拿房经理看到是下雨免费给我们升级了比较近的房间免去了我们冒雨坐楼巴的尴尬，再到途中发现纸巾用完呼叫服务请求纸巾都体验到被服务的感觉，反馈都很到位。美中不足的是冲凉房的水温，有点太猛了，感觉就像在淋温泉，太烫了摸索了一阵子我快熟了。话说周边绿化也是真的非常棒，就感觉住在一个森林中，空气是广州没有的那种清新，每个毛孔都很享受。公园里有一个设定值得一说，当你每走一段路地上会有一段话，就像我人生路的领悟呀。“看图的风景，不如身临其境”当时就把我看蒙了。很有那个味道。总得来说这次是个非常好的体验，不愧是你，**。这种树林森林与住宅的搭配真的很是我的菜。爱了爱了，下次再会
# --------------------
#
#
# ---------16149---------
#
#
# ---------16150---------
# --------------------
# 环境总体还不错
# --------
# 总体环境不错
# --------------------
#
#
# ---------16151---------
# --------------------
# 房间很大很好。
# --------
# 很好，房间很大！
# --------------------
#
#
# ---------16152---------
#
#
# ---------16153---------
# --------------------
# 装修太老了，服务一般般
# --------
# 装修太老了，服务一般般
# --------------------
#
#
# ---------16154---------
#
#
# ---------16155---------
#
#
# ---------16156---------
#
#
# ---------16157---------
#
#
# ---------16158---------
#
#
# ---------16159---------
# --------------------
# 很不错服务好
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务挺不错
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务不错很好
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务好，不错
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务很不错！
# --------------------
# --------------------
# 很不错服务好
# --------
# 不错服务挺好
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务很不错
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务不错
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务好不错
# --------------------
# --------------------
# 很不错服务好
# --------
# 服务好不错
# --------------------
#
#
# ---------16160---------
#
#
# ---------16161---------
#
#
# ---------16162---------
#
#
# ---------16163---------
#
#
# ---------16164---------
#
#
# ---------16165---------
#
#
# ---------16166---------
#
#
# ---------16167---------
#
#
# ---------16168---------
#
#
# ---------16169---------
#
#
# ---------16170---------
#
#
# ---------16171---------
#
#
# ---------16172---------
#
#
# ---------16173---------
#
#
# ---------16174---------
#
#
# ---------16175---------
#
#
# ---------16176---------
# --------------------
# 出行方便、交通便利！
# --------
# 交通方便！
# --------------------
# --------------------
# 出行方便、交通便利！
# --------
# 交通好，出行方便
# --------------------
#
#
# ---------16177---------
#
#
# ---------16178---------
#
#
# ---------16179---------
#
#
# ---------16180---------
#
#
# ---------16181---------
# --------------------
# 什么鬼五星酒店，什么服务都没有，态度还不好，酒店还陈旧，还强迫我给好评
# --------
# 这个什么鬼五星酒店，什么服务都没有，态度还不好，酒店还陈旧，还强迫我给好评
# --------------------
#
#
# ---------16182---------
#
#
# ---------16183---------
#
#
# ---------16184---------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 挺好！服务员态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好呀
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好。
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 非常好服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好美金
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度 环境都很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
#
#
# ---------16185---------
# --------------------
# 环境还不错
# --------
# 环境还不错
# --------------------
# --------------------
# 环境还不错
# --------
# 环境还不错
# --------------------
# --------------------
# 环境还不错
# --------
# 环境不错哦
# --------------------
# --------------------
# 环境还不错
# --------
# 环境不错哦
# --------------------
# --------------------
# 环境还不错
# --------
# 环境还算不错
# --------------------
# --------------------
# 环境还不错
# --------
# 环境还不错
# --------------------
# --------------------
# 环境还不错
# --------
# 环境不错的
# --------------------
#
#
# ---------16186---------
#
#
# ---------16187---------
#
#
# ---------16188---------
#
#
# ---------16189---------
# --------------------
# 交通便利，价格合适
# --------
# 价格合适，交通便利
# --------------------
#
#
# ---------16190---------
#
#
# ---------16191---------
#
#
# ---------16192---------
#
#
# ---------16193---------
#
#
# ---------16194---------
# --------------------
# 可以，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# --------
# 接待客户，，，，**酒店还是不错的选择，，，，，，干净卫生，，，，，，，，，，，，，，，，，，，，，，
# --------------------
# --------------------
# 可以，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# --------
# ？好，，，，，
# --------------------
# --------------------
# 可以，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# --------
# 不错，，，，，，，，，
# --------------------
# --------------------
# 可以，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# --------
# ，，，，，
# --------------------
#
#
# ---------16195---------
#
#
# ---------16196---------
#
#
# ---------16197---------
#
#
# ---------16198---------
# --------------------
# 不错，房间很好
# --------
# 房间很不错
# --------------------
#
#
# ---------16199---------
#
#
# ---------16200---------
#
#
# ---------16201---------
#
#
# ---------16202---------
#
#
# ---------16203---------
#
#
# ---------16204---------
#
#
# ---------16205---------
#
#
# ---------16206---------
#
#
# ---------16207---------
# --------------------
# 很棒，服务态度也很好，很棒
# --------
# 服务好，很棒
# --------------------
# --------------------
# 很棒，服务态度也很好，很棒
# --------
# 非常好，服务态度也很好
# --------------------
#
#
# ---------16208---------
#
#
# ---------16209---------
#
#
# ---------16210---------
#
#
# ---------16211---------
#
#
# ---------16212---------
#
#
# ---------16213---------
#
#
# ---------16214---------
#
#
# ---------16215---------
#
#
# ---------16216---------
#
#
# ---------16217---------
#
#
# ---------16218---------
#
#
# ---------16219---------
#
#
# ---------16220---------
#
#
# ---------16221---------
#
#
# ---------16222---------
#
#
# ---------16223---------
#
#
# ---------16224---------
#
#
# ---------16225---------
#
#
# ---------16226---------
#
#
# ---------16227---------
#
#
# ---------16228---------
#
#
# ---------16229---------
#
#
# ---------16230---------
#
#
# ---------16231---------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 哇好好好的
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 五星级酒店服务一级棒，好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 不错，好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好 ^_^
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好！
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好啊好啊好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好好好好好好
# --------
# 好好好好好
# --------------------
#
#
# ---------16232---------
#
#
# ---------16233---------
#
#
# ---------16234---------
#
#
# ---------16235---------
#
#
# ---------16236---------
#
#
# ---------16237---------
#
#
# ---------16238---------
#
#
# ---------16239---------
#
#
# ---------16240---------
#
#
# ---------16241---------
#
#
# ---------16242---------
#
#
# ---------16243---------
#
#
# ---------16244---------
#
#
# ---------16245---------
#
#
# ---------16246---------
#
#
# ---------16247---------
#
#
# ---------16248---------
#
#
# ---------16249---------
#
#
# ---------16250---------
#
#
# ---------16251---------
#
#
# ---------16252---------
#
#
# ---------16253---------
#
#
# ---------16254---------
#
#
# ---------16255---------
#
#
# ---------16256---------
#
#
# ---------16257---------
#
#
# ---------16258---------
#
#
# ---------16259---------
#
#
# ---------16260---------
# --------------------
# 人不多，亲子游，挺好。早餐送到房间，干净卫生。人不多，亲子游，挺好。早餐送到房间，干净卫生。只有一家餐厅可以吃饭。
# --------
# 人不多，亲子游，挺好。早餐送到房间，干净卫生。人不多，亲子游，挺好。早餐送到房间，干净卫生。只有一家餐厅开
# --------------------
#
#
# ---------16261---------
#
#
# ---------16262---------
#
#
# ---------16263---------
#
#
# ---------16264---------
#
#
# ---------16265---------
#
#
# ---------16266---------
#
#
# ---------16267---------
#
#
# ---------16268---------
#
#
# ---------16269---------
#
#
# ---------16270---------
#
#
# ---------16271---------
#
#
# ---------16272---------
#
#
# ---------16273---------
#
#
# ---------16274---------
#
#
# ---------16275---------
#
#
# ---------16276---------
#
#
# ---------16277---------
#
#
# ---------16278---------
#
#
# ---------16279---------
#
#
# ---------16280---------
#
#
# ---------16281---------
# --------------------
# 环境很好，服务也很好
# --------
# 环境服务都很好，清馨美女服务也很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 服务很好，环境很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 挺好，不错！环境和服务都很好！
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 服务很好，环境也不错。
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境非常好，服务很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 酒店环境很不错，服务态度也很好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境很好，服务很到位，
# --------------------
# --------------------
# 环境很好，服务也很好
# --------
# 环境服务都很好
# --------------------
#
#
# ---------16282---------
#
#
# ---------16283---------
#
#
# ---------16284---------
#
#
# ---------16285---------
#
#
# ---------16286---------
# --------------------
# 服務很好，房間很乾淨
# --------
# 服務很好，房間很乾淨
# --------------------
#
#
# ---------16287---------
#
#
# ---------16288---------
# --------------------
# 适合带孩子
# --------
# 适合带孩子去
# --------------------
# --------------------
# 适合带孩子
# --------
# 适合带孩子玩
# --------------------
# --------------------
# 适合带孩子
# --------
# 适合带孩子
# --------------------
# --------------------
# 适合带孩子
# --------
# 适合带孩子
# --------------------
# --------------------
# 适合带孩子
# --------
# 适合带孩子
# --------------------
#
#
# ---------16289---------
#
#
# ---------16290---------
#
#
# ---------16291---------
#
#
# ---------16292---------
#
#
# ---------16293---------
#
#
# ---------16294---------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还算不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 还不错酒店
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
# --------------------
# 酒店还不错
# --------
# 酒店还不错
# --------------------
#
#
# ---------16295---------
#
#
# ---------16296---------
#
#
# ---------16297---------
#
#
# ---------16298---------
#
#
# ---------16299---------
#
#
# ---------16300---------
#
#
# ---------16301---------
#
#
# ---------16302---------
#
#
# ---------16303---------
#
#
# ---------16304---------
# --------------------
# 环境好，服务好！
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境不错，服务态度好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务好，环境好，不错
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 好环境，好服务
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 酒店环境好，服务态度又好！
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 服务态度好，环境好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好 服务好 棒
# --------------------
# --------------------
# 环境好，服务好！
# --------
# 环境好，服务好
# --------------------
#
#
# ---------16305---------
#
#
# ---------16306---------
#
#
# ---------16307---------
#
#
# ---------16308---------
#
#
# ---------16309---------
#
#
# ---------16310---------
#
#
# ---------16311---------
#
#
# ---------16312---------
#
#
# ---------16313---------
# --------------------
# 挺不错。环境很好
# --------
# 环境很不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境很不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境挺不错的
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境很不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境很不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 不错，环境很好
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境挺不错的
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境挺不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 不错，环境很好
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 环境很不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 挺好的环境不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 挺好的，环境不错
# --------------------
# --------------------
# 挺不错。环境很好
# --------
# 很不错的，环境好
# --------------------
#
#
# ---------16314---------
#
#
# ---------16315---------
#
#
# ---------16316---------
#
#
# ---------16317---------
#
#
# ---------16318---------
# --------------------
# 自助晚餐质量待提高，其它都还好
# --------
# 自助晚餐质量有待提高，其它都还好
# --------------------
#
#
# ---------16319---------
#
#
# ---------16320---------
#
#
# ---------16321---------
#
#
# ---------16322---------
#
#
# ---------16323---------
#
#
# ---------16324---------
#
#
# ---------16325---------
#
#
# ---------16326---------
#
#
# ---------16327---------
#
#
# ---------16328---------
#
#
# ---------16329---------
#
#
# ---------16330---------
#
#
# ---------16331---------
#
#
# ---------16332---------
#
#
# ---------16333---------
#
#
# ---------16334---------
#
#
# ---------16335---------
#
#
# ---------16336---------
#
#
# ---------16337---------
#
#
# ---------16338---------
#
#
# ---------16339---------
# --------------------
# 服务好，环境好
# --------
# 环境不错，服务态度好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务好，环境好，不错
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务很好，环境很好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务好、环境好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 服务好，环境好
# --------
# 酒店环境好，服务态度又好！
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务态度好，环境好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境服务好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 服务到位，环境很好
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好 服务好 棒
# --------------------
# --------------------
# 服务好，环境好
# --------
# 环境好，服务好
# --------------------
#
#
# ---------16340---------
#
#
# ---------16341---------
#
#
# ---------16342---------
#
#
# ---------16343---------
# --------------------
# 好好好好好
# --------
# 哇好好好的
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 五星级酒店服务一级棒，好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 不错，好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好 ^_^
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好！
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好啊好啊好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
#
#
# ---------16344---------
#
#
# ---------16345---------
# --------------------
# 还算不错吧
# --------
# 还算不错吧
# --------------------
#
#
# ---------16346---------
#
#
# ---------16347---------
#
#
# ---------16348---------
#
#
# ---------16349---------
#
#
# ---------16350---------
#
#
# ---------16351---------
#
#
# ---------16352---------
#
#
# ---------16353---------
#
#
# ---------16354---------
#
#
# ---------16355---------
#
#
# ---------16356---------
#
#
# ---------16357---------
#
#
# ---------16358---------
#
#
# ---------16359---------
#
#
# ---------16360---------
#
#
# ---------16361---------
# ---------16362---------
#
#
# ---------16363---------
#
#
# ---------16364---------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比高。
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高！
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比高！
# --------------------
# --------------------
# 性价比很高
# --------
# 性价比很高
# --------------------
#
#
# ---------16365---------
#
#
# ---------16366---------
# --------------------
# 很好非常好
# --------
# 很好，非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 很好，非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 非常好，很好
# --------------------
# --------------------
# 很好非常好
# --------
# 非常好 非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 很好，非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 好非常非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 非常的很好
# --------------------
# --------------------
# 很好非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 很好，非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 好很好非常好
# --------------------
# --------------------
# 很好非常好
# --------
# 很好，非常好
# --------------------
#
#
# ---------16367---------
#
#
# ---------16368---------
#
#
# ---------16369---------
#
#
# ---------16370---------
#
#
# ---------16371---------
#
#
# ---------16372---------
#
#
# ---------16373---------
#
#
# ---------16374---------
#
#
# ---------16375---------
#
#
# ---------16376---------
#
#
# ---------16377---------
#
#
# ---------16378---------
# --------------------
# 住了多次了
# --------
# 住了多次了
# --------------------
#
#
# ---------16379---------
#
#
# ---------16380---------
#
#
# ---------16381---------
#
#
# ---------16382---------
# --------------------
# 环境不错，服务态度好
# --------
# 服务好，环境好，不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好好，前台服务不错约
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务好 环境不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务态度不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境不错！服务态度好美金
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 酒店环境很不错，服务态度也很好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 酒店环境好，服务态度又好！
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务态度好，环境好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境可以，服务态度不错
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 服务态度 环境都很好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境不错，服务态度好
# --------
# 客服服务态度好。环境不错
# --------------------
#
#
# ---------16383---------
#
#
# ---------16384---------
#
#
# ---------16385---------
# --------------------
# 环境挺好的
# --------
# 环境挺好的
# --------------------
# --------------------
# 环境挺好的
# --------
# 环境挺好的
# --------------------
# --------------------
# 环境挺好的
# --------
# 环境挺好的
# --------------------
# --------------------
# 环境挺好的
# --------
# 挺好的环境不错
# --------------------
# --------------------
# 环境挺好的
# --------
# 环境挺好的
# --------------------
#
#
# ---------16386---------
#
#
# ---------16387---------
# --------------------
# 房间很好.服务不错
# --------
# 服务不错房间也挺好
# --------------------
#
#
# ---------16388---------
#
#
# ---------16389---------
#
#
# ---------16390---------
#
#
# ---------16391---------
#
#
# ---------16392---------
#
#
# ---------16393---------
#
#
# ---------16394---------
#
#
# ---------16395---------
#
#
# ---------16396---------
#
#
# ---------16397---------
#
#
# ---------16398---------
#
#
# ---------16399---------
#
#
# ---------16400---------
#
#
# ---------16401---------
#
#
# ---------16402---------
#
#
# ---------16403---------
#
#
# ---------16404---------
#
#
# ---------16405---------
#
#
# ---------16406---------
#
#
# ---------16407---------
#
#
# ---------16408---------
#
#
# ---------16409---------
# --------------------
# 环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。有特别的提醒服务，房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------
# 早餐挺好，房间也还行，稍微有点老。环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------------------
# --------------------
# 环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。有特别的提醒服务，房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------
# 环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。有特别的开床服务，房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------------------
# --------------------
# 环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。有特别的提醒服务，房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------
# 环境优美，地理位置好，交通方便，房间舒适卫生，服务人员很热情，乐于提供各种帮助，早餐丰富。设施很人性化，网络高速信号好，窗外风景好。有特别的开床服务，房间小摆件的设计也很有特色。性价比不错，下次还要入住
# --------------------
#
#
# ---------16410---------
#
#
# ---------16411---------
#
#
# ---------16412---------
#
#
# ---------16413---------
#
#
# ---------16414---------
#
#
# ---------16415---------
#
#
# ---------16416---------
# --------------------
# 玩的还行，吃的太差。找点吃的太难了！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# --------
# 好！！！！！！！！！！！！！！
# --------------------
# --------------------
# 玩的还行，吃的太差。找点吃的太难了！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# --------
# 好！！！！！！！！！！！
# --------------------
# --------------------
# 玩的还行，吃的太差。找点吃的太难了！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# --------
# 很好！！！！！！！
# --------------------
#
#
# ---------16417---------
#
#
# ---------16418---------
# --------------------
# 酒店房间挺大，就是有点旧
# --------
# 酒店房间大，但有点旧
# --------------------
#
#
# ---------16419---------
#
#
# ---------16420---------
#
#
# ---------16421---------
#
#
# ---------16422---------
#
#
# ---------16423---------
#
#
# ---------16424---------
#
#
# ---------16425---------
# --------------------
# 环境优美，服务一流，
# --------
# 服务一流，居住环境优美
# --------------------
# --------------------
# 环境优美，服务一流，
# --------
# 环境优美，服务一流
# --------------------
#
#
# ---------16426---------
# --------------------
# 玩得开心，不错
# --------
# 不错，玩得很开心
# --------------------
#
#
# ---------16427---------
#
#
# ---------16428---------
#
#
# ---------16429---------
#
#
# ---------16430---------
#
#
# ---------16431---------
#
#
# ---------16432---------
#
#
# ---------16433---------
#
#
# ---------16434---------
#
#
# ---------16435---------
#
#
# ---------16436---------
#
#
# ---------16437---------
#
#
# ---------16438---------
#
#
# ---------16439---------
#
#
# ---------16440---------
#
#
# ---------16441---------
#
#
# ---------16442---------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好好，前台服务不错约
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务好 环境不错
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 挺好，不错！环境和服务都很好！
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务很好，环境也不错。
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务好，不错
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 好环境，好服务
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境和服务挺好的，不错
# --------------------
# --------------------
# 服务好，环境好，不错
# --------
# 环境好，服务好
# --------------------
#
#
# ---------16443---------
#
#
# ---------16444---------
#
#
# ---------16445---------
# --------------------
# 早餐丰富，停车方便，环境好
# --------
# 早餐丰富，停车方便
# --------------------
# --------------------
# 早餐丰富，停车方便，环境好
# --------
# 早餐丰富，停车方便
# --------------------
# --------------------
# 早餐丰富，停车方便，环境好
# --------
# 停车位很方便，早餐很丰富！
# --------------------
#
#
# ---------16446---------
# --------------------
# 整体感觉一般
# --------
# 整体感觉一般
# --------------------
#
#
# ---------16447---------
# --------------------
# 停车方便，环境安静
# --------
# 很安静，环境也不错，停车方便
# --------------------
#
#
# ---------16448---------
# --------------------
# 环境优美，早餐丰富
# --------
# 早餐丰富，环境美
# --------------------
#
#
# ---------16449---------
#
#
# ---------16450---------
#
#
# ---------16451---------
#
#
# ---------16452---------
# --------------------
# 游泳不错。
# --------
# 游泳馆不错。
# --------------------
#
#
# ---------16453---------
#
#
# ---------16454---------
#
#
# ---------16455---------
#
#
# ---------16456---------
#
#
# ---------16457---------
#
#
# ---------16458---------
#
#
# ---------16459---------
#
#
# ---------16460---------
# --------------------
# 很好，环境好
# --------
# 环境很好！
# --------------------
# --------------------
# 很好，环境好
# --------
# 环境很好。
# --------------------
# --------------------
# 很好，环境好
# --------
# 环境很好很好
# --------------------
# --------------------
# 很好，环境好
# --------
# 环境很好！
# --------------------
# --------------------
# 很好，环境好
# --------
# 环境很好。
# --------------------
# --------------------
# 很好，环境好
# --------
# 环境很好。
# --------------------
# --------------------
# 很好，环境好
# --------
# 好，环境好，好
# --------------------
#
#
# ---------16461---------
#
#
# ---------16462---------
#
#
# ---------16463---------
#
#
# ---------16464---------
#
#
# ---------16465---------
#
#
# ---------16466---------
#
#
# ---------16467---------
#
#
# ---------16468---------
#
#
# ---------16469---------
#
#
# ---------16470---------
# --------------------
# 挺好的体验
# --------
# 很好的体验
# --------------------
#
#
# ---------16471---------
# --------------------
# 酒店环境优美
# --------
# 酒店环境优美
# --------------------
#
#
# ---------16472---------
#
#
# ---------16473---------
#
#
# ---------16474---------
#
#
# ---------16475---------
#
#
# ---------16476---------
#
#
# ---------16477---------
#
#
# ---------16478---------
#
#
# ---------16479---------
#
#
# ---------16480---------
#
#
# ---------16481---------
#
#
# ---------16482---------
#
#
# ---------16483---------
#
#
# ---------16484---------
#
#
# ---------16485---------
#
#
# ---------16486---------
#
#
# ---------16487---------
#
#
# ---------16488---------
#
#
# ---------16489---------
#
#
# ---------16490---------
#
#
# ---------16491---------
#
#
# ---------16492---------
#
#
# ---------16493---------
#
#
# ---------16494---------
#
#
# ---------16495---------
#
#
# ---------16496---------
#
#
# ---------16497---------
#
#
# ---------16498---------
#
#
# ---------16499---------
#
#
# ---------16500---------
#
#
# ---------16501---------
#
#
# ---------16502---------
#
#
# ---------16503---------
#
#
# ---------16504---------
#
#
# ---------16505---------
#
#
# ---------16506---------
#
#
# ---------16507---------
# --------------------
# 环境不错，值得推荐
# --------
# 环境不错。值得推荐
# --------------------
#
#
# ---------16508---------
# --------------------
# 环境舒服不错
# --------
# 环境舒服 不错
# --------------------
#
#
# ---------16509---------
#
#
# ---------16510---------
#
#
# ---------16511---------
#
#
# ---------16512---------
#
#
# ---------16513---------
#
#
# ---------16514---------
#
#
# ---------16515---------
#
#
# ---------16516---------
#
#
# ---------16517---------
#
#
# ---------16518---------
#
#
# ---------16519---------
#
#
# ---------16520---------
#
#
# ---------16521---------
#
#
# ---------16522---------
#
#
# ---------16523---------
#
#
# ---------16524---------
# --------------------
# 房间舒适，服务好
# --------
# 服务好，房间干净舒适。
# --------------------
#
#
# ---------16525---------
#
#
# ---------16526---------
#
#
# ---------16527---------
#
#
# ---------16528---------
#
#
# ---------16529---------
#
#
# ---------16530---------
#
#
# ---------16531---------
#
#
# ---------16532---------
#
#
# ---------16533---------
#
#
# ---------16534---------
#
#
# ---------16535---------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错啊
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错哟
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错不错不错不错不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 不错 不错 不错
# --------
# 不错不错哦
# --------------------
#
#
# ---------16536---------
#
#
# ---------16537---------
#
#
# ---------16538---------
#
#
# ---------16539---------
# --------------------
# 房间卫生挺干净的
# --------
# 房间不错，干净卫生
# --------------------
# --------------------
# 房间卫生挺干净的
# --------
# 房间干净卫生
# --------------------
#
#
# ---------16540---------
#
#
# ---------16541---------
#
#
# ---------16542---------
#
#
# ---------16543---------
#
#
# ---------16544---------
#
#
# ---------16545---------
#
#
# ---------16546---------
#
#
# ---------16547---------
#
#
# ---------16548---------
#
#
# ---------16549---------
#
#
# ---------16550---------
#
#
# ---------16551---------
#
#
# ---------16552---------
#
#
# ...
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 好，服务很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务很好。
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务很好。
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务很好，
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务很好的
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务很好呀
# --------
# 服务挺好的
# --------------------
#
#
# ---------17214---------
#
#
# ---------17215---------
#
#
# ---------17216---------
#
#
# ---------17217---------
#
#
# ---------17218---------
#
#
# ---------17219---------
#
#
# ---------17220---------
#
#
# ---------17221---------
#
#
# ---------17222---------
#
#
# ---------17223---------
#
#
# ---------17224---------
#
#
# ---------17225---------
#
#
# ---------17226---------
# --------------------
# 服务好呀。
# --------
# 服务很好。
# --------------------
# --------------------
# 服务好呀。
# --------
# 服务很好。
# --------------------
#
#
# ---------17227---------
#
#
# ---------17228---------
# --------------------
# 挺好的 很干净。前台态度也很好。一楼休闲吧拍照很漂亮。灯光很好看。周围吃的很多。好吃的也很多，楼下有7 11 很方便。
# --------
# 挺好的 很干净。前台态度也很好。一楼休闲吧拍照很漂亮。灯光很好看。周围吃的很多。好吃的也很多，楼下有7 11 很方便。
# --------------------
#
#
# ---------17229---------
#
#
# ---------17230---------
#
#
# ---------17231---------
#
#
# ---------17232---------
#
#
# ---------17233---------
#
#
# ---------17234---------
#
#
# ---------17235---------
#
#
# ---------17236---------
#
#
# ---------17237---------
#
#
# ---------17238---------
#
#
# ---------17239---------
# --------------------
# 不错，很好
# --------
# 挺好的，不错
# --------------------
# --------------------
# 不错，很好
# --------
# 不错，挺好的
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，不错
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，很不错
# --------------------
# --------------------
# 不错，很好
# --------
# 不错，挺好的
# --------------------
# --------------------
# 不错，很好
# --------
# 挺好的好，不错，
# --------------------
# --------------------
# 不错，很好
# --------
# 挺好的，不错
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，不错
# --------------------
# --------------------
# 不错，很好
# --------
# 好好好，很不错
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，很不错
# --------------------
# --------------------
# 不错，很好
# --------
# 好德很，不错！
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，不错！
# --------------------
# --------------------
# 不错，很好
# --------
# 不错的 很好
# --------------------
# --------------------
# 不错，很好
# --------
# 很好，不错。
# --------------------
#
#
# ---------17240---------
#
#
# ---------17241---------
#
#
# ---------17242---------
# --------------------
# 服务不错，早餐挺好吃的
# --------
# 早餐不错，服务好
# --------------------
#
#
# ---------17243---------
#
#
# ---------17244---------
#
#
# ---------17245---------
#
#
# ---------17246---------
# --------------------
# 環境不錯??
# --------
# 環境不錯??
# --------------------
# --------------------
# 環境不錯??
# --------
# 環境不錯??
# --------------------
#
#
# ---------17247---------
# --------------------
# 環境不錯??
# --------
# 環境不錯??
# --------------------
#
#
# ---------17248---------
#
#
# ---------17249---------
#
#
# ---------17250---------
#
#
# ---------17251---------
#
#
# ---------17252---------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好！
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
#
#
# ---------17253---------
#
#
# ---------17254---------
#
#
# ---------17255---------
#
#
# ---------17256---------
#
#
# ---------17257---------
#
#
# ---------17258---------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好。
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
#
#
# ---------17259---------
#
#
# ---------17260---------
#
#
# ---------17261---------
# --------------------
# 环境非常好
# --------
# 非常好的环境
# --------------------
# --------------------
# 环境非常好
# --------
# 非常好环境好
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常好
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常好！
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常好
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常好，
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常棒
# --------------------
# --------------------
# 环境非常好
# --------
# 环境非常好
# --------------------
#
#
# ---------17262---------
# --------------------
# 非常好的环境
# --------
# 非常好环境好
# --------------------
# --------------------
# 非常好的环境
# --------
# 环境非常好
# --------------------
# --------------------
# 非常好的环境
# --------
# 环境非常好！
# --------------------
# --------------------
# 非常好的环境
# --------
# 环境非常好
# --------------------
# --------------------
# 非常好的环境
# --------
# 环境非常好，
# --------------------
# --------------------
# 非常好的环境
# --------
# 环境非常好
# --------------------
#
#
# ---------17263---------
#
#
# ---------17264---------
#
#
# ---------17265---------
#
#
# ---------17266---------
# --------------------
# 非常好，很干净
# --------
# 非常的好，干净
# --------------------
# --------------------
# 非常好，很干净
# --------
# 很好，非常干净
# --------------------
#
#
# ---------17267---------
# --------------------
# 酒店卫生干净，服务好
# --------
# 酒店服务好，专业干净卫生！
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 干净卫生服务好！
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好，卫生干净
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 环境好，服务好，干净卫生
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好，干净卫生
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好！卫生干净
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好干净卫生
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好，卫生干净
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 服务好卫生干净
# --------------------
# --------------------
# 酒店卫生干净，服务好
# --------
# 卫生干净，服务好
# --------------------
#
#
# ---------17268---------
#
#
# ---------17269---------
# --------------------
# 很好，安静，舒服
# --------
# 安静，舒服，环境好
# --------------------
#
#
# ---------17270---------
#
#
# ---------17271---------
#
#
# ---------17272---------
#
#
# ---------17273---------
#
#
# ---------17274---------
#
#
# ---------17275---------
#
#
# ---------17276---------
#
#
# ---------17277---------
#
#
# ---------17278---------
#
#
# ---------17279---------
# --------------------
# 态度都很好 还很送到楼上外卖 态度很好?? 前台 收拾房间的阿姨都很好。
# --------
# 态度都很好 还很送到楼上外卖 态度很好?? 前台 收拾房间的阿姨都很好。
# --------------------
#
#
# ---------17280---------
#
#
# ---------17281---------
#
#
# ---------17282---------
#
#
# ---------17283---------
#
#
# ---------17284---------
#
#
# ---------17285---------
#
#
# ---------17286---------
#
#
# ---------17287---------
#
#
# ---------17288---------
# --------------------
# 挺好的酒店
# --------
# 很好的酒店
# --------------------
# --------------------
# 挺好的酒店
# --------
# 很好的酒店
# --------------------
# --------------------
# 挺好的酒店
# --------
# 酒店挺好的
# --------------------
# --------------------
# 挺好的酒店
# --------
# 很好的酒店
# --------------------
# --------------------
# 挺好的酒店
# --------
# 很好的酒店
# --------------------
# --------------------
# 挺好的酒店
# --------
# 酒店挺好的
# --------------------
# --------------------
# 挺好的酒店
# --------
# 很好的酒店
# --------------------
#
#
# ---------17289---------
#
#
# ---------17290---------
#
#
# ---------17291---------
#
#
# ---------17292---------
#
#
# ---------17293---------
#
#
# ---------17294---------
#
#
# ---------17295---------
#
#
# ---------17296---------
#
#
# ---------17297---------
#
#
# ---------17298---------
# --------------------
# 很好很好的
# --------
# 很好的很好
# --------------------
# --------------------
# 很好很好的
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好很好的
# --------
# 很好很好很厚好！
# --------------------
# --------------------
# 很好很好的
# --------
# 很好很好！
# --------------------
# --------------------
# 很好很好的
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好很好的
# --------
# 都很好很好
# --------------------
# --------------------
# 很好很好的
# --------
# 很好很好很好
# --------------------
#
#
# ---------17299---------
# --------------------
# 很好的很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好的很好
# --------
# 很好很好很厚好！
# --------------------
# --------------------
# 很好的很好
# --------
# 很好很好！
# --------------------
# --------------------
# 很好的很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好的很好
# --------
# 都很好很好
# --------------------
# --------------------
# 很好的很好
# --------
# 很好很好很好
# --------------------
#
#
# ---------17300---------
# --------------------
# 服务很好，环境很好
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境舒服，服务很好。
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境非常好，服务很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 酒店环境很不错，服务态度也很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境很好，服务很到位，
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 服务到位，环境很好
# --------------------
# --------------------
# 服务很好，环境很好
# --------
# 环境好，服务好
# --------------------
#
#
# ---------17301---------
#
#
# ---------17302---------
#
#
# ---------17303---------
#
#
# ---------17304---------
# --------------------
# 很不错，设计好，服务好，干净卫生
# --------
# 服务很好，卫生很好，干净
# --------------------
#
#
# ---------17305---------
# --------------------
# 床舒适服务很好
# --------
# 服务好，床舒适
# --------------------
#
#
# ---------17306---------
#
#
# ---------17307---------
#
#
# ---------17308---------
#
#
# ---------17309---------
#
#
# ---------17310---------
#
#
# ---------17311---------
#
#
# ---------17312---------
# --------------------
# 位置好，方便，小茹服务态度很好
# --------
# 环境好，位置方便，前台服务好
# --------------------
#
#
# ---------17313---------
#
#
# ---------17314---------
#
#
# ---------17315---------
#
#
# ---------17316---------
#
#
# ---------17317---------
#
#
# ---------17318---------
#
#
# ---------17319---------
#
#
# ---------17320---------
#
#
# ---------17321---------
#
#
# ---------17322---------
#
#
# ---------17323---------
#
#
# ---------17324---------
#
#
# ---------17325---------
#
#
# ---------17326---------
#
#
# ---------17327---------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 五星级酒店服务一级棒，好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 不错，好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好 ^_^
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好！
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好啊好啊好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
#
#
# ---------17328---------
# --------------------
# 房间干净，早餐也不错，
# --------
# 早餐不错，房间干净
# --------------------
#
#
# ---------17329---------
#
#
# ---------17330---------
#
#
# ---------17331---------
#
#
# ---------17332---------
#
#
# ---------17333---------
#
#
# ---------17334---------
# --------------------
# 很好的体验
# --------
# 很好的体验。
# --------------------
#
#
# ---------17335---------
# --------------------
# 各方面都很好
# --------
# 各方面都很好！
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好
# --------
# 各方面都很好
# --------------------
#
#
# ---------17336---------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都很好！
# --------
# 各方面都很好
# --------------------
#
#
# ---------17337---------
#
#
# ---------17338---------
#
#
# ---------17339---------
#
#
# ---------17340---------
#
#
# ---------17341---------
#
#
# ---------17342---------
# --------------------
# 服务非常满意，清馨服务态度特别好
# --------
# 非常满意，服务态度好
# --------------------
#
#
# ---------17343---------
#
#
# ---------17344---------
# --------------------
# 不错啊 地理位置好
# --------
# 地理位置很不错
# --------------------
