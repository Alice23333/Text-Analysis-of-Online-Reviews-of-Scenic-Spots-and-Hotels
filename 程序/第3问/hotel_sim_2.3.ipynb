# %% [markdown]
# # 求酒店评论相似度并提取相似的评论

# %% [markdown]
# ## 1 导入库和酒店评论数据

# %%
import pandas as pd
import jieba 
data = pd.read_csv("./酒店评论.csv",encoding='gbk',dtype=str)  # 载入全部数据
data = data["评论内容"]
data
# Out:
# 0                                                酒店很适合家庭出行
# 1                                            升级了房间 延迟退房 很赞
# 2        这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...
# 3                                                   酒店很好不错
# 4                                                    超五星好评
#                                ...
# 24775    酒店是老字号宾馆，虽然有装修过但设施比较陈旧房间空调比较小，卫生间里的墙壁有剥落现象，浴室的...
# 24776          本人觉得还好，价格偏高，没有很高档，服务是很好，设施偏老，也不会很大，喜欢楼下的早茶。
# 24777                                         隔音极差，睡眠让人崩溃。
# 24778                                       酒店位置很好，停车场比较小。
# 24779                                     位置好找，停车方便，酒店太老了！
# Name: 评论内容, Length: 24780, dtype: object

# %% [markdown]
# ## 2 求余弦相似度

# %% [markdown]
# ### 2.1 导入gensim模块

# %% [markdown]
# gensim模块用于自然语言处理，使用其中Word2Vec库将每一条评论文本转换为词向量再计算两个词向量之间的余弦相似度，相似度大于（）时为几乎相同的评论。

# %%
import numpy as np
from gensim.models import Word2Vec

model = Word2Vec(data)
w2i = {w: i for i, w in enumerate(model.wv.index_to_key, 1)}
vectors = np.concatenate((np.zeros((1, 100)), model.wv.vectors), axis=0)
w2v = lambda w: vectors[w2i.get(w, 0)]

# %% [markdown]
# ### 2.2 计算$c_m,k=0..N-1$和$c_n,n=k+1..N$的余弦相似度，提取相似的评论

# %%
for k in range(int(2*(len(data)-1)/20),int(3*(len(data)-1)/20)):
    vec1 = np.mean([w2v(w) for w in data[k]], axis=0)
    print("---------"+str(k)+"---------")
    for j in range(k+1,len(data)):
        vec2 = np.mean([w2v(w) for w in data[j]], axis=0)
        if np.linalg.norm(vec1) * np.linalg.norm(vec2) != 0:
            rate = vec1 @ vec2 / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
            if rate > 0.95:
                print("--------------------\n"+data[k]+"\n--------")
                print(data[j]+"\n--------------------")
    print("\n")
# Out:
# ---------2477---------
# --------------------
# 环境舒适干净，服务很到位！
# --------
# 环境很舒适，服务很好
# --------------------
# --------------------
# 环境舒适干净，服务很到位！
# --------
# 服务到位环境舒适
# --------------------
# --------------------
# 环境舒适干净，服务很到位！
# --------
# 服务很好，酒店舒适干净
# --------------------
# --------------------
# 环境舒适干净，服务很到位！
# --------
# 服务很好，酒店干净舒适
# --------------------
#
#
# ---------2478---------
#
#
# ---------2479---------
# --------------------
# 小如服务很好小赖人也不错环境也很好
# --------
# 服务很好卫生做的不错环境也不错小茹人很好小赖也是
# --------------------
# --------------------
# 小如服务很好小赖人也不错环境也很好
# --------
# 前台服务很好小茹茹人不错，环境也好
# --------------------
#
#
# ---------2480---------
#
#
# ---------2481---------
#
#
# ---------2482---------
#
#
# ---------2483---------
#
#
# ---------2484---------
#
#
# ---------2485---------
# --------------------
# 停车场免费
# --------
# 有免费的停车场
# --------------------
# --------------------
# 停车场免费
# --------
# 有停车场可以免费停车
# --------------------
# --------------------
# 停车场免费
# --------
# 有免费停车
# --------------------
# --------------------
# 停车场免费
# --------
# 有免费停车场
# --------------------
# --------------------
# 停车场免费
# --------
# 停车场是免费的
# --------------------
# --------------------
# 停车场免费
# --------
# 免费停车场
# --------------------
#
#
# ---------2486---------
#
#
# ---------2487---------
#
#
# ---------2488---------
#
#
# ---------2489---------
#
#
# ---------2490---------
#
#
# ---------2491---------
# --------------------
# 服务很好前台小如人不错
# --------
# 前台服务很好小如人很好
# --------------------
#
#
# ---------2492---------
#
#
# ---------2493---------
#
#
# ---------2494---------
#
#
# ---------2495---------
#
#
# ---------2496---------
#
#
# ---------2497---------
#
#
# ---------2498---------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度佳
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好！
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务好，态度佳
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务很好，态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 都很好！服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度很好。
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度特别好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 阿姨服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务员态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好不
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好。
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 前台服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度好
# --------
# 服务态度很好
# --------------------
#
#
# ---------2499---------
#
#
# ---------2500---------
#
#
# ---------2501---------
#
#
# ---------2502---------
#
#
# ---------2503---------
#
#
# ---------2504---------
#
#
# ---------2505---------
#
#
# ---------2506---------
#
#
# ---------2507---------
#
#
# ---------2508---------
#
#
# ---------2509---------
#
#
# ---------2510---------
# --------------------
# 回家的感觉
# --------
# 回家的感觉
# --------------------
#
#
# ---------2511---------
#
#
# ---------2512---------
#
#
# ---------2513---------
# --------------------
# 酒店环境很好卫生很干净，小茹人好小赖人也不错
# --------
# 服务很好卫生做的不错环境也不错小茹人很好小赖也是
# --------------------
#
#
# ---------2514---------
# --------------------
# 前台服务好，廖女士很不错。房间卫生好
# --------
# 前台小林服务限好，房间很不错
# --------------------
#
#
# ---------2515---------
#
#
# ---------2516---------
#
#
# ---------2517---------
#
#
# ---------2518---------
#
#
# ---------2519---------
#
#
# ---------2520---------
#
#
# ---------2521---------
#
#
# ---------2522---------
#
#
# ---------2523---------
#
#
# ---------2524---------
#
#
# ---------2525---------
#
#
# ---------2526---------
#
#
# ---------2527---------
#
#
# ---------2528---------
#
#
# ---------2529---------
#
#
# ---------2530---------
# --------------------
# 小刘服务好
# --------
# 小赖服务好
# --------------------
# --------------------
# 小刘服务好
# --------
# 罗小姐服务好
# --------------------
# --------------------
# 小刘服务好
# --------
# 前台小朱服务好
# --------------------
# --------------------
# 小刘服务好
# --------
# 前台小沈服务好
# --------------------
# --------------------
# 小刘服务好
# --------
# 小朱服务很好
# --------------------
# --------------------
# 小刘服务好
# --------
# 小茹服务很好
# --------------------
#
#
# ---------2531---------
# --------------------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了一晚，现在去还有很大的折扣，大堂林经理非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了两晚，现在去还有很大的折扣，大堂林经理非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------------------
# --------------------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了一晚，现在去还有很大的折扣，大堂林经理非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了两晚，现在去还有很大的折扣，大堂梁先生非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------------------
# ---------2532---------
# --------------------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了两晚，现在去还有很大的折扣，大堂林经理非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------
# 第一次入住，入住感觉很好，本来就住一晚，结果又加了两晚，现在去还有很大的折扣，大堂梁先生非常热情，有问题都一一解答，很有耐心，服务态度很好，酒店泳池没得说。干净。自助餐也很上档次，对的起五星酒店，酒店位置绝佳无论去市区还是去动物园都很方便。另外礼宾部的阿昆也很热情服务周到！因为本人不喜欢拍照就没有拍图，但是入住感觉非常好！
# --------------------
#
#
# ---------2533---------
#
#
# ---------2534---------
#
#
# ---------2535---------
# --------------------
# 很好，小刘服务很好
# --------
# 小毛服务很好
# --------------------
# --------------------
# 很好，小刘服务很好
# --------
# 小朱服务很好
# --------------------
# --------------------
# 很好，小刘服务很好
# --------
# 小茹服务很好
# --------------------
#
#
# ---------2536---------
#
#
# ---------2537---------
#
#
# ---------2538---------
#
#
# ---------2539---------
#
#
# ---------2540---------
# --------------------
# 前台服务很好经常过来小如服务不错环境卫生不错小赖人也好
# --------
# 前台服务很好小茹茹人不错，环境也好
# --------------------
#
#
# ---------2541---------
#
#
# ---------2542---------
#
#
# ---------2543---------
#
#
# ---------2544---------
#
#
# ---------2545---------
#
#
# ---------2546---------
#
#
# ---------2547---------
#
#
# ---------2548---------
#
#
# ---------2549---------
#
#
# ---------2550---------
#
#
# ---------2551---------
#
#
# ---------2552---------
#
#
# ---------2553---------
# --------------------
# 大堂服务优秀石头服务不错佩林优秀
# --------
# 大堂服务优秀
# --------------------
#
#
# ---------2554---------
#
#
# ---------2555---------
#
#
# ---------2556---------
#
#
# ---------2557---------
#
#
# ---------2558---------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境不错，服务人员态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度非常不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 挺不错的 服务态度好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境很好，服务态度很不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境不错服务态度好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境不错，服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错的
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很不错
# --------
# 服务态度很好
# --------------------
#
#
# ---------2559---------
# --------------------
# 酒店很漂亮
# --------
# 酒店很漂亮
# --------------------
#
#
# ---------2560---------
#
#
# ---------2561---------
#
#
# ---------2562---------
#
#
# ---------2563---------
#
#
# ---------2564---------
#
#
# ---------2565---------
#
#
# ---------2566---------
# --------------------
# 谢谢酒[强][强][强][强][强]店员工的热情服务，**酒店老早就听说了在北京名气很大，这次家人外出就奔着他们的名气而去 果然没有让我及家人失望，一进入大厅Adam的服务就感受到热情好客的氛围，主动提拿行李箱热情问候。房间干净卫生，疫情期间消毒做的非常到位。[玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰]仁义服务也不错
# --------
# 酒店服务谢谢酒[强][强][强][强][强]店员工的热情服务，**酒店老早就听说了在北京名气很大，这次家人外出就奔着他们的名气而去 果然没有让我及家人失望，一进入大厅杜小姐的服务就感受到热情好客的氛围，主动提拿行李箱热情问候。房间干净卫生，疫情期间消毒做的非常到位。[玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰][玫瑰]
# --------------------
#
#
# ---------2567---------
# --------------------
# 五星级酒店五星级的家，**酒店曾经是世界一流酒店组织的成员，作为国内五星级酒店服务态度很好做的十分到位，感谢前厅部Adam及missa的热情服务[握手]。酒店管理非常人性化，主动周到每个服务人员热情 大厅一股淡淡的奶香味十分喜欢 。
# --------
# 五星级酒店五星级的家，**酒店曾经是世界一流酒店组织的成员，作为国内五星级酒店服务态度很好做的十分到位，感谢前厅部missa及安娜周语上的热情服务[握手]。酒店管理非常人性化，主动周到每个服务人员热情?? 大厅一股淡淡的奶香味十分喜欢?? 。
# --------------------
#
#
# ---------2568---------
#
#
# ---------2569---------
#
#
# ---------2570---------
#
#
# ---------2571---------
#
#
# ---------2572---------
#
#
# ---------2573---------
#
#
# ---------2574---------
#
#
# ---------2575---------
# --------------------
# 大堂经理梁志强先生服务好
# --------
# 大堂梁经理服务好
# --------------------
#
#
# ---------2576---------
#
#
# ---------2577---------
#
#
# ---------2578---------
#
#
# ---------2579---------
#
#
# ---------2580---------
#
#
# ---------2581---------
#
#
# ---------2582---------
#
#
# ---------2583---------
#
#
# ---------2584---------
#
#
# ---------2585---------
#
#
# ---------2586---------
#
#
# ---------2587---------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错 不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错好
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错啊不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错啊
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错的
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错啊
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错哟
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 非常好，不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错不错不错不错不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错不错
# --------------------
# --------------------
# 朋友都反应杜经理服务态度好极了佩林也不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# --------
# 不错不错哦
# --------------------
#
#
# ---------2588---------
#
#
# ---------2589---------
#
#
# ---------2590---------
#
#
# ---------2591---------
#
#
# ---------2592---------
#
#
# ---------2593---------
# --------------------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂副理Adam林服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有杜经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]点赞一百次.
# --------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂副理Benz Leung林服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有杜经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]点赞一百次.
# --------------------
# --------------------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂副理Adam林服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有杜经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]点赞一百次.
# --------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂梁先生服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有杜经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]
# --------------------
# --------------------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂副理Adam林服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有杜经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]点赞一百次.
# --------
# 酒店位置优越，交通十分方便，距离火车南站只有二十分钟左右就可以到达，酒店的绿化富有岭南特色，非常有意境。大堂副理Benz Leung服务态度非常满意，优秀!房间的卫生干净整洁，感觉像新开的酒店一样十分新!还有马经理的服务也十分周到热情。[玫瑰][玫瑰][玫瑰][玫瑰]点赞一百次.
# --------------------
#
#
# ---------2594---------
#
#
# ---------2595---------
#
#
# ---------2596---------
#
#
# ---------2597---------
# --------------------
# 非常好小石
# --------
# 小朱非常好
# --------------------
#
#
# ---------2598---------
#
#
# ---------2599---------
# --------------------
# 环境好，服务好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 酒店环境好 服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务都好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 非常好，服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境棒！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务，环境都很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境，服务很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境不错
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务环境都很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境挺好服务也好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务态度很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 酒店环境不错，服务态度好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务环境都好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好、环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好、环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境很好，服务更好。
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务都好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，态度好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境不错
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务态度好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务态度好，酒店环境不错
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境很好，服务也好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务态度很好环境也好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境 服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好。
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境不错，服务态度很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 酒店环境很好，服务态度很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境不错，服务态度好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好，不错
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务很好，环境很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好、环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 环境好，服务好
# --------
# 酒店环境好，服务态度又好！
# --------------------
# --------------------
# 环境好，服务好
# --------
# 服务态度好，环境好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境不错，服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好 服务好 棒
# --------------------
# --------------------
# 环境好，服务好
# --------
# 环境好，服务好
# --------------------
# ---------2600---------
#
#
# ---------2601---------
#
#
# ---------2602---------
#
#
# ---------2603---------
#
#
# ---------2604---------
#
#
# ---------2605---------
#
#
# ---------2606---------
#
#
# ---------2607---------
#
#
# ---------2608---------
# --------------------
# 挺好，不错。
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好，不错，。
# --------------------
# --------------------
# 挺好，不错。
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 很好不错。
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好，不错。
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的好，不错，
# --------------------
# --------------------
# 挺好，不错。
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好，不错。
# --------
# 很好，不错。
# --------------------
#
#
# ---------2609---------
# --------------------
# 在广告上看到过**酒店的简介，到达酒店果然不负所望，大堂杜韵经理的服务态度非常好。客房的服务人员也非常不错，感谢楼层主管谢袁进的辛勤劳动。房间干净卫生，疫情消毒非常到位安心。大堂气派，酒店旁边就是木栈道饭后散步  非常好的去处，环境优美，前台 礼宾服务态度很好。下次继续来入住**酒店。
# --------
# 在广告上看到过**酒店的简介，到达酒店果然名副其实，大堂环境安静舒适，小谢、梁先生的服务态度非常好，热情周到，超五星服务。客房的服务人员也非常不错。房间干净卫生，疫情消毒非常到位安心。大堂气派，酒店旁边就是木栈道饭后散步 非常好的去处，环境优美，前台 礼宾服务态度很好。下次继续来入住**酒店。
# --------------------
# --------------------
# 在广告上看到过**酒店的简介，到达酒店果然不负所望，大堂杜韵经理的服务态度非常好。客房的服务人员也非常不错，感谢楼层主管谢袁进的辛勤劳动。房间干净卫生，疫情消毒非常到位安心。大堂气派，酒店旁边就是木栈道饭后散步  非常好的去处，环境优美，前台 礼宾服务态度很好。下次继续来入住**酒店。
# --------
# 在广告上看到过**酒店的简介，到达酒店果然名副其实，大堂环境安静舒适，米莎、小梁的服务态度非常好，热情周到，超五星服务。客房的服务人员也非常不错。房间干净卫生，疫情消毒非常到位安心。大堂气派，酒店旁边就是木栈道饭后散步 非常好的去处，环境优美，前台 礼宾服务态度很好。下次继续来入住**酒店。推荐！
# --------------------
#
#
# ---------2610---------
#
#
# ---------2611---------
#
#
# ---------2612---------
#
#
# ---------2613---------
#
#
# ---------2614---------
#
#
# ---------2615---------
#
#
# ---------2616---------
#
#
# ---------2617---------
#
#
# ---------2618---------
#
#
# ---------2619---------
#
#
# ---------2620---------
# --------------------
# 前台服务不错
# --------
# 前台服务态度不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 好评前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错哦
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务挺不错的约
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错的啊
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务挺不错的哦
# --------------------
# --------------------
# 前台服务不错
# --------
# 好评前台服务不错
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错！
# --------------------
# --------------------
# 前台服务不错
# --------
# 前台服务不错
# --------------------
#
#
# ---------2621---------
#
#
# ---------2622---------
#
#
# ---------2623---------
#
#
# ---------2624---------
#
#
# ---------2625---------
#
#
# ---------2626---------
#
#
# ---------2627---------
#
#
# ---------2628---------
#
#
# ---------2629---------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台小朱服务好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台小沈服务好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 小朱服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台小朱服务态度很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 骆小姐服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 小茹服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 前台服务很好
# --------------------
# --------------------
# 前台小石服务很好
# --------
# 酒店前台小姐姐服务很好
# --------------------
#
#
# ---------2630---------
#
#
# ---------2631---------
#
#
# ---------2632---------
#
#
# ---------2633---------
#
#
# ---------2634---------
#
#
# ---------2635---------
#
#
# ---------2636---------
#
#
# ---------2637---------
#
#
# ---------2638---------
#
#
# ---------2639---------
#
#
# ---------2640---------
#
#
# ---------2641---------
#
#
# ---------2642---------
# --------------------
# 环境很好，很舒服
# --------
# 环境很好，很舒服
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 很好，很舒服
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 环境不错，很舒服
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 环境很好，很卫生，很舒服
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 住的很舒服，环境很好
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 环境舒服，服务很好。
# --------------------
# --------------------
# 环境很好，很舒服
# --------
# 环境好，很舒服
# --------------------
#
#
# ---------2643---------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁 舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 整洁干净舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 卫生整洁干净舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁，舒适！
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁舒适
# --------------------
# --------------------
# 干净整洁舒适
# --------
# 干净整洁舒适
# --------------------
#
#
# ---------2644---------
# --------------------
# 小赖服务好
# --------
# 罗小姐服务好
# --------------------
# --------------------
# 小赖服务好
# --------
# 前台小朱服务好
# --------------------
# --------------------
# 小赖服务好
# --------
# 前台小沈服务好
# --------------------
# --------------------
# 小赖服务好
# --------
# 小朱服务很好
# --------------------
# --------------------
# 小赖服务好
# --------
# 骆小姐服务很好
# --------------------
# --------------------
# 小赖服务好
# --------
# 小茹服务很好
# --------------------
#
#
# ---------2645---------
# --------------------
# 礼宾部陈森服务好
# --------
# 礼宾部杜韵服务很好
# --------------------
#
#
# ---------2646---------
#
#
# ---------2647---------
#
#
# ---------2648---------
#
#
# ---------2649---------
#
#
# ---------2650---------
# --------------------
# 酒店环境很好前台小谢跟小李服务很好，周围环境也不错
# --------
# 前台服务很好小茹茹人不错，环境也好
# --------------------
# --------------------
# 酒店环境很好前台小谢跟小李服务很好，周围环境也不错
# --------
# 小梁服务很好环境不错。
# --------------------
#
#
# ---------2651---------
#
#
# ---------2652---------
# --------------------
# 酒店环境非常好 前台服务好 石先生 马女士都不错
# --------
# 酒店环境很好，前台服务好佩奇女士 石先生
# --------------------
#
#
# ---------2653---------
#
#
# ---------2654---------
#
#
# ---------2655---------
#
#
# ---------2656---------
#
#
# ---------2657---------
# --------------------
# 酒店前台啊发服务态度非常好
# --------
# 前台服务非常好
# --------------------
#
#
# ---------2658---------
#
#
# ---------2659---------
#
#
# ---------2660---------
#
#
# ---------2661---------
# --------------------
# 一般般吧.....
# --------
# 一般.....
# --------------------
#
#
# ---------2662---------
#
#
# ---------2663---------
#
#
# ---------2664---------
#
#
# ---------2665---------
#
#
# ---------2666---------
#
#
# ---------2667---------
#
#
# ---------2668---------
#
#
# ---------2669---------
#
#
# ---------2670---------
#
#
# ---------2671---------
#
#
# ---------2672---------
#
#
# ---------2673---------
#
#
# ---------2674---------
#
#
# ---------2675---------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都挺好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都挺好的
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
# --------------------
# 各方面都好
# --------
# 各方面都很好
# --------------------
#
#
# ---------2676---------
#
#
# ---------2677---------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好！
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置挺好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置非常好。
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置很好。
# --------
# 酒店位置很好哦
# --------------------
#
#
# ---------2678---------
#
#
# ---------2679---------
#
#
# ---------2680---------
#
#
# ---------2681---------
#
#
# ---------2682---------
#
#
# ---------2683---------
# --------------------
# 酒店服务设施齐全林先生服务态度好
# --------
# 酒店服务设施齐全收割服务态度非常好
# --------------------
#
#
# ---------2684---------
#
#
# ---------2685---------
# --------------------
# 小杜服务很好，很满意
# --------
# 服务很好，很满意
# --------------------
# --------------------
# 小杜服务很好，很满意
# --------
# 服务很好，很满意
# --------------------
#
#
# ---------2686---------
#
#
# ---------2687---------
#
#
# ---------2688---------
# --------------------
# 挺不错的。。。。
# --------
# 还不错。。。。
# --------------------
# --------------------
# 挺不错的。。。。
# --------
# 不错。。。。。。
# --------------------
# --------------------
# 挺不错的。。。。
# --------
# 不错的。。
# --------------------
# --------------------
# 挺不错的。。。。
# --------
# 桌球挺不错的。。。。。。
# --------------------
#
#
# ---------2689---------
#
#
# ---------2690---------
#
#
# ---------2691---------
#
#
# ---------2692---------
#
#
# ---------2693---------
#
#
# ---------2694---------
#
#
# ---------2695---------
#
#
# ---------2696---------
#
#
# ---------2697---------
#
#
# ---------2698---------
#
#
# ---------2699---------
#
#
# ---------2700---------
#
#
# ---------2701---------
#
#
# ---------2702---------
# --------------------
# 前台服务很好小茹茹人不错，环境也好
# --------
# 酒店环境不错的马小姐，春兰服务态度很好
# --------------------
# --------------------
# 前台服务很好小茹茹人不错，环境也好
# --------
# 小梁服务很好环境不错。
# --------------------
# --------------------
# 前台服务很好小茹茹人不错，环境也好
# --------
# 环境不错，酒店服务也不错，前台小叶服务很热情
# --------------------
# --------------------
# 前台服务很好小茹茹人不错，环境也好
# --------
# 前台服务很好环境不错
# --------------------
# --------------------
# 前台服务很好小茹茹人不错，环境也好
# --------
# 环境好好，前台服务不错约
# --------------------
#
#
# ---------2703---------
#
#
# ---------2704---------
#
#
# ---------2705---------
#
#
# ---------2706---------
#
#
# ---------2707---------
#
#
# ---------2708---------
#
#
# ---------2709---------
#
#
# ---------2710---------
#
#
# ---------2711---------
#
#
# ---------2712---------
#
#
# ---------2713---------
#
#
# ---------2714---------
#
#
# ---------2715---------
#
#
# ---------2716---------
#
#
# ---------2717---------
#
#
# ---------2718---------
#
#
# ---------2719---------
#
#
# ---------2720---------
#
#
# ---------2721---------
#
#
# ---------2722---------
#
#
# ---------2723---------
#
#
# ---------2724---------
#
#
# ---------2725---------
#
#
# ---------2726---------
# --------------------
# 设施和环境都不错
# --------
# 环境设施都不错
# --------------------
# --------------------
# 设施和环境都不错
# --------
# 环境设施不错
# --------------------
# --------------------
# 设施和环境都不错
# --------
# 设施和环境都挺好
# --------------------
#
#
# ---------2727---------
#
#
# ---------2728---------
#
#
# ---------2729---------
# --------------------
# 非常好，很满意
# --------
# 很好，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常满意，非常好！
# --------------------
# --------------------
# 非常好，很满意
# --------
# 很好，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 挺好的 非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 挺好的，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 满意 非常好
# --------------------
# --------------------
# 非常好，很满意
# --------
# 很好，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，满意！
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常满意，非常好
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，非常满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，很满意
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常满意，很好
# --------------------
# --------------------
# 非常好，很满意
# --------
# 非常好，非常满意
# --------------------
#
#
# ---------2730---------
#
#
# ---------2731---------
#
#
# ---------2732---------
#
#
# ---------2733---------
#
#
# ---------2734---------
#
#
# ---------2735---------
#
#
# ---------2736---------
#
#
# ---------2737---------
#
#
# ---------2738---------
#
#
# ---------2739---------
#
#
# ---------2740---------
#
#
# ---------2741---------
#
#
# ---------2742---------
#
#
# ---------2743---------
# --------------------
# 前台小刘服务很热情
# --------
# 前台小刘服务热情周到
# --------------------
# --------------------
# 前台小刘服务很热情
# --------
# 前台服务热情
# --------------------
# --------------------
# 前台小刘服务很热情
# --------
# 前台服务很热情！
# --------------------
# --------------------
# 前台小刘服务很热情
# --------
# 小哥哥服务很热情
# --------------------
# --------------------
# 前台小刘服务很热情
# --------
# 前台麦小姐服务不错、非常热情
# --------------------
#
#
# ---------2744---------
#
#
# ---------2745---------
#
#
# ---------2746---------
#
#
# ---------2747---------
#
#
# ---------2748---------
#
#
# ---------2749---------
#
#
# ---------2750---------
#
#
# ---------2751---------
#
#
# ---------2752---------
#
#
# ---------2753---------
#
#
# ---------2754---------
#
#
# ---------2755---------
#
#
# ---------2756---------
# --------------------
# 酒店服务非常好！
# --------
# 非常好的酒店！服务很好
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 非常好的酒店！服务很好！
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 酒店服务非常好
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 酒店服务非常好！
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 服务非常好！
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 酒店服务非常好
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 酒店服务很好！
# --------------------
# --------------------
# 酒店服务非常好！
# --------
# 酒店前台服务态度非常好，酒店环境也非常好
# --------------------
#
#
# ---------2757---------
#
#
# ---------2758---------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ?????? ???? ????? ????? ???????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ???? ???? ????? ????. ???? ?? ???? ???? ??? ?? ??????. ????? ???? ??????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 很棒哦哦????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 环境超美，前台小姐姐李沫池服务非常贴心??????铂金酒店铂金服务????????????????????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ????? ? ????? ?????? ??? ??
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ? ??? ????? ??? ?? ?? ? ? ???? ??????? ?????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 酒店不错，会经常回来的！=((( ????)动感光波哔哔哔!!!??????*??*??????-??-??????*??*?-??-?
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 非常好????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ?????.????? ??????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ??? ???? ?? ???? ??? ???? ?? ????? ??? ???? ?? ???? .. ???? ??? ??? ??? ??? ?? ?? ??????. ????? ???? ???? ?? ?? ???? ???? ???? ?? ??? ????.???? ? ???? ?? ??? ??. ??? ???? ?? ??? ?? ???? ???. ???? ?? ?? ?????? ?? ???? ? ?? ?? ???? ? ?? ??? ??? ?? ?? ??? ????.
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 很好??????????。我
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 很不错??????????。
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 酒店非常不错??????????????????????????????????????????????????????????????????????????????????????????????????????????????????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 前台服务态度很好??????????开心??
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 酒店不错，会经常回来的！=((( ????)动感光波哔哔哔!!!??????*??*??????-??-??????*??*?-??-?
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ?????? ?? ??? ????? ? ??? ???? ??? ?? ? ?????. ??? ??? ?? ?? ????? ???? ?? ?????.
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ??? ??? ?? ????^^ ?? ?? ???? ???? ?????.3??? ? ??? ?? ??? ?? ?????^^
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 好(? ??_??)?
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# ?? ??? ???? ?? ????????. ??????? ??? ???? ?????. ????.
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 挺好的，还送了早餐??????????????????????????????????????????????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 非常好????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 不错??????
# --------------------
# --------------------
# 酒店服务态度很好????????????????????????????????????????????，早餐吃的好大厅林先生刘先生啊发服务态度很好
# --------
# 很好??不错????
# --------------------
#
#
# ---------2759---------
#
#
# ---------2760---------
#
#
# ---------2761---------
#
#
# ---------2762---------
# --------------------
# 前台小刘服务热情周到
# --------
# 前台小姐姐好热情 服务也周到
# --------------------
# --------------------
# 前台小刘服务热情周到
# --------
# 前台小宋热情周到！
# --------------------
#
#
# ---------2763---------
#
#
# ---------2764---------
#
#
# ---------2765---------
# --------------------
# 大堂梁经理服务好
# --------
# 大堂经理梁服务很好
# --------------------
# --------------------
# 大堂梁经理服务好
# --------
# 大堂经理服务很好
# --------------------
#
#
# ---------2766---------
#
#
# ---------2767---------
#
#
# ---------2768---------
#
#
# ---------2769---------
#
#
# ---------2770---------
#
#
# ---------2771---------
# --------------------
# 酒店很漂亮，环境很好。前台服务好，梁先生，石先生服务好。
# --------
# 酒店环境很好，前台服务好佩奇女士 石先生
# --------------------
#
#
# ---------2772---------
#
#
# ---------2773---------
#
#
# ---------2774---------
#
#
# ---------2775---------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度佳
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好！
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好呦
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好 舒服
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务好，态度佳
# --------------------
# --------------------
# 服务态度很好
# --------
# 环境好，服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好，态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 都很好！服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台服务态度很好。
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度特别好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 酒店服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# ...
# 还不错！！
# --------
# 还不错哦！
# --------------------
#
#
# ---------3630---------
#
#
# ---------3631---------
#
#
# ---------3632---------
#
#
# ---------3633---------
#
#
# ---------3634---------
#
#
# ---------3635---------
#
#
# ---------3636---------
#
#
# ---------3637---------
#
#
# ---------3638---------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好，非常棒
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常非常的好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常棒
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好 非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 好非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常好非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好。
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# --------------------
# 非常非常好
# --------
# 非常非常好
# --------------------
# ---------3639---------
#
#
# ---------3640---------
# --------------------
# 环境优美好
# --------
# 环境优美！
# --------------------
# --------------------
# 环境优美好
# --------
# 环境优美，
# --------------------
# --------------------
# 环境优美好
# --------
# 环境很优美
# --------------------
# --------------------
# 环境优美好
# --------
# 环境优美。
# --------------------
# --------------------
# 环境优美好
# --------
# 环境优美。
# --------------------
# --------------------
# 环境优美好
# --------
# 环境好优美。
# --------------------
# --------------------
# 环境优美好
# --------
# 环境很优美
# --------------------
#
#
# ---------3641---------
# --------------------
# 很好，挺舒适的
# --------
# 很好，很舒适
# --------------------
#
#
# ---------3642---------
# --------------------
# 很好 很好
# --------
# 很好很好！
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好！
# --------------------
# --------------------
# 很好 很好
# --------
# 很好 很好的
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好啦
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好的
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好啊
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好的
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好，很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好的
# --------------------
# --------------------
# 很好 很好
# --------
# 很好的很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很厚好！
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好！
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
# --------------------
# 很好 很好
# --------
# 很好很好很好
# --------------------
#
#
# ---------3643---------
#
#
# ---------3644---------
#
#
# ---------3645---------
#
#
# ---------3646---------
#
#
# ---------3647---------
#
#
# ---------3648---------
#
#
# ---------3649---------
#
#
# ---------3650---------
#
#
# ---------3651---------
#
#
# ---------3652---------
#
#
# ---------3653---------
#
#
# ---------3654---------
#
#
# ---------3655---------
#
#
# ---------3656---------
#
#
# ---------3657---------
#
#
# ---------3658---------
#
#
# ---------3659---------
#
#
# ---------3660---------
# --------------------
# 好。。。。。。。。。
# --------
# 房间一般，温泉很不结。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 环境确实不错，高大上。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# OK。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好评。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 还行。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 不错。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 办事太慢。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 老顾客了，好评。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 老顾客了，好评。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 帮同事预定的，反映不错。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 不出的，同事满意，还会再来定的。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 超级好的酒店，完全没有任何毛病。非常好的体验。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 价格便宜，离办事地点也近。。。。。。。。。。。。。。。。。。。。。。。。，。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 好。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 不错。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 不错不错，服务很好，查房很快不需要等。 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
# --------------------
# 好。。。。。。。。。
# --------
# 很好的酒店。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# --------------------
#
#
# ---------3661---------
#
#
# ---------3662---------
#
#
# ---------3663---------
#
#
# ---------3664---------
#
#
# ---------3665---------
#
#
# ---------3666---------
# --------------------
# 环境优美 服务好
# --------
# 周边环境优美,服务好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 服务好，环境优美，
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务态度很好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务态度好。
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务态度好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务态度很好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美服务态度好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 前台服务好，环境优美！
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，态度好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美，服务态度很好
# --------------------
# --------------------
# 环境优美 服务好
# --------
# 环境优美 服务周到
# --------------------
#
#
# ---------3667---------
#
#
# ---------3668---------
#
#
# ---------3669---------
# --------------------
# 适合带孩子去玩
# --------
# 适合带孩子玩。
# --------------------
# --------------------
# 适合带孩子去玩
# --------
# 适合带孩子去玩！
# --------------------
# --------------------
# 适合带孩子去玩
# --------
# 适合带孩子去
# --------------------
# --------------------
# 适合带孩子去玩
# --------
# 适合带孩子玩
# --------------------
#
#
# ---------3670---------
#
#
# ---------3671---------
#
#
# ---------3672---------
#
#
# ---------3673---------
#
#
# ---------3674---------
#
#
# ---------3675---------
# --------------------
# 挺好的。下次还来
# --------
# 挺好的 下次还来
# --------------------
# --------------------
# 挺好的。下次还来
# --------
# 挺好的 下次还来
# --------------------
# --------------------
# 挺好的。下次还来
# --------
# 挺好的，下次再来
# --------------------
#
#
# ---------3676---------
#
#
# ---------3677---------
#
#
# ---------3678---------
#
#
# ---------3679---------
# --------------------
# 前台很热情
# --------
# 前台很热情
# --------------------
#
#
# ---------3680---------
#
#
# ---------3681---------
# --------------------
# 很满意，酒店
# --------
# 酒店很好，满意！
# --------------------
#
#
# ---------3682---------
#
#
# ---------3683---------
#
#
# ---------3684---------
#
#
# ---------3685---------
# --------------------
# 泳池非常大 小孩子玩的很开心
# --------
# 泳池非常棒 孩子玩的很开心
# --------------------
#
#
# ---------3686---------
#
#
# ---------3687---------
# --------------------
# 酒店很不错！
# --------
# 很不错的酒店！
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 很不错的酒店！
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错！
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 很不错酒店
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错
# --------------------
# --------------------
# 酒店很不错！
# --------
# 酒店很不错！
# --------------------
#
#
# ---------3688---------
#
#
# ---------3689---------
# --------------------
# 环境，服务很好
# --------
# 环境服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务，环境都很好。
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很不错，位置很好，服务态度好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务环境都很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境挺好服务也好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务态度很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境不错，服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务更好。
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务态度很不错
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务也好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务态度很好环境也好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境 服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务都很好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好。
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好 服务很周到
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好服务不错
# --------------------
# --------------------
# 环境，服务很好
# --------
# 酒店环境，服务态度都很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务都很棒
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境不错，服务态度很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境不错哦，服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 酒店环境很好，服务态度很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境不错，服务很好。
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务也很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务都很好，清馨美女服务也很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务很好，环境很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务不错，环境很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境舒服，服务很好。
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境非常好，服务很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好！
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 酒店环境很不错，服务态度也很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境很好，服务很到位，
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务到位，环境很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 服务态度 环境都很好
# --------------------
# --------------------
# 环境，服务很好
# --------
# 环境好，服务好
# --------------------
#
#
# ---------3690---------
#
#
# ---------3691---------
#
#
# ---------3692---------
#
#
# ---------3693---------
#
#
# ---------3694---------
#
#
# ---------3695---------
#
#
# ---------3696---------
#
#
# ---------3697---------
#
#
# ---------3698---------
#
#
# ---------3699---------
#
#
# ---------3700---------
# --------------------
# 环境优美！
# --------
# 环境优美，
# --------------------
# --------------------
# 环境优美！
# --------
# 环境很优美
# --------------------
# --------------------
# 环境优美！
# --------
# 环境优美，赞
# --------------------
# --------------------
# 环境优美！
# --------
# 环境优美。
# --------------------
# --------------------
# 环境优美！
# --------
# 环境优美。
# --------------------
# --------------------
# 环境优美！
# --------
# 环境很优美
# --------------------
#
#
# ---------3701---------
#
#
# ---------3702---------
#
#
# ---------3703---------
#
#
# ---------3704---------
#
#
# ---------3705---------
#
#
# ---------3706---------
#
#
# ---------3707---------
#
#
# ---------3708---------
# --------------------
# 服务各方面都很好
# --------
# 各方面服务都好
# --------------------
# --------------------
# 服务各方面都很好
# --------
# 服务态度各方面都挺好的。
# --------------------
# --------------------
# 服务各方面都很好
# --------
# 很好，服务各方面都不错
# --------------------
#
#
# ---------3709---------
#
#
# ---------3710---------
#
#
# ---------3711---------
#
#
# ---------3712---------
# --------------------
# 挺好的 下次还来
# --------
# 挺好的 下次还来
# --------------------
# --------------------
# 挺好的 下次还来
# --------
# 挺好的，下次再来
# --------------------
#
#
# ---------3713---------
#
#
# ---------3714---------
#
#
# ---------3715---------
