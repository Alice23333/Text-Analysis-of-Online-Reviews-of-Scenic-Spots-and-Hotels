# %% [markdown]
# # 求景区评论相似度并提取相似的评论

# %% [markdown]
# ## 1 导入库和酒店评论数据

# %%
import pandas as pd
import jieba 
data = pd.read_csv("./酒店评论.csv",encoding='gbk',dtype=str)  # 载入全部数据
data = data["评论内容"]
data
# Out:
# 0                                                酒店很适合家庭出行
# 1                                            升级了房间 延迟退房 很赞
# 2        这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...
# 3                                                   酒店很好不错
# 4                                                    超五星好评
#                                ...
# 24775    酒店是老字号宾馆，虽然有装修过但设施比较陈旧房间空调比较小，卫生间里的墙壁有剥落现象，浴室的...
# 24776          本人觉得还好，价格偏高，没有很高档，服务是很好，设施偏老，也不会很大，喜欢楼下的早茶。
# 24777                                         隔音极差，睡眠让人崩溃。
# 24778                                       酒店位置很好，停车场比较小。
# 24779                                     位置好找，停车方便，酒店太老了！
# Name: 评论内容, Length: 24780, dtype: object

# %% [markdown]
# ## 2 求余弦相似度

# %% [markdown]
# ### 2.1 导入gensim模块

# %% [markdown]
# gensim模块用于自然语言处理，使用其中Word2Vec库将每一条评论文本转换为词向量再计算两个词向量之间的余弦相似度，相似度大于（）时为几乎相同的评论。

# %%
import numpy as np
from gensim.models import Word2Vec

model = Word2Vec(data)
w2i = {w: i for i, w in enumerate(model.wv.index_to_key, 1)}
vectors = np.concatenate((np.zeros((1, 100)), model.wv.vectors), axis=0)
w2v = lambda w: vectors[w2i.get(w, 0)]

# %% [markdown]
# ### 2.2 计算$c_m,k=0..N-1$和$c_n,n=k+1..N$的余弦相似度，提取相似的评论

# %%
for k in range(int(9*(len(data)-1)/20),int(10*(len(data)-1)/20)):
    vec1 = np.mean([w2v(w) for w in data[k]], axis=0)
    print("---------"+str(k)+"---------")
    for j in range(k+1,len(data)):
        vec2 = np.mean([w2v(w) for w in data[j]], axis=0)
        if np.linalg.norm(vec1) * np.linalg.norm(vec2) != 0:
            rate = vec1 @ vec2 / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
            if rate > 0.95:
                print("--------------------\n"+data[k]+"\n--------")
                print(data[j]+"\n--------------------")
    print("\n")
# Out:
# ---------11150---------
# --------------------
# 服务很好，不错，很热情，值得推荐入住，1052好
# --------
# 服务很好，很不错，值得推荐入住，1052
# --------------------
#
#
# ---------11151---------
# --------------------
# 服务很好，很不错，值得推荐入住，1052
# --------
# 很好，很不错，推荐入住， 1052很好
# --------------------
# --------------------
# 服务很好，很不错，值得推荐入住，1052
# --------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------------------
# --------------------
# 服务很好，很不错，值得推荐入住，1052
# --------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------------------
# --------------------
# 服务很好，很不错，值得推荐入住，1052
# --------
# 很好，很不错，推荐入住，前台很好1052
# --------------------
# --------------------
# 服务很好，很不错，值得推荐入住，1052
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11152---------
# --------------------
# 环境不错...........服务很好.998
# --------
# 不错 环境干净整洁卫生 服务态度很好...............................
# --------------------
#
#
# ---------11153---------
#
#
# ---------11154---------
#
#
# ---------11155---------
#
#
# ---------11156---------
# --------------------
# 挺好的 前台1052小姐姐很好 楼面服务员也很热情
# --------
# 挺好的 前台1052小姐姐人很好 楼面服务员也很热情
# --------------------
#
#
# ---------11157---------
#
#
# ---------11158---------
#
#
# ---------11159---------
#
#
# ---------11160---------
#
#
# ---------11161---------
# --------------------
# 好，很方便的
# --------
# 很好方便的很
# --------------------
#
#
# ---------11162---------
#
#
# ---------11163---------
#
#
# ---------11164---------
#
#
# ---------11165---------
#
#
# ---------11166---------
#
#
# ---------11167---------
#
#
# ---------11168---------
# --------------------
# 酒店停车很方便
# --------
# 停车很方便
# --------------------
# --------------------
# 酒店停车很方便
# --------
# 停车很方便
# --------------------
# --------------------
# 酒店停车很方便
# --------
# 停车方便很好
# --------------------
# --------------------
# 酒店停车很方便
# --------
# 酒店停车方便
# --------------------
#
#
# ---------11169---------
# --------------------
# 性价比不错
# --------
# 性价比不错
# --------------------
# --------------------
# 性价比不错
# --------
# 不错，性价比
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比不错
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比不错。
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比不错
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比还算不错
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比很不错
# --------------------
# --------------------
# 性价比不错
# --------
# 性价比不错。
# --------------------
#
#
# ---------11170---------
# --------------------
# 性价比很好
# --------
# 性价比很好
# --------------------
# --------------------
# 性价比很好
# --------
# 性价比挺好
# --------------------
#
#
# ---------11171---------
#
#
# ---------11172---------
#
#
# ---------11173---------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
# --------------------
# 环境还可以
# --------
# 环境还可以
# --------------------
#
#
# ---------11174---------
# --------------------
# 交通很便利
# --------
# 挺好交通便利
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很方便
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很方便！
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很便利
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很方便
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很便利
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很方便
# --------------------
# --------------------
# 交通很便利
# --------
# 交通便利好
# --------------------
# --------------------
# 交通很便利
# --------
# 交通很方便
# --------------------
#
#
# ---------11175---------
#
#
# ---------11176---------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好！
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好的好幻好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 哇好好好的
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 五星级酒店服务一级棒，好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 不错，好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好 ^_^
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好！
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好啊好啊好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好好好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
# --------------------
# 好好好好好
# --------
# 好好好好好
# --------------------
#
#
# ---------11177---------
#
#
# ---------11178---------
#
#
# ---------11179---------
# --------------------
# 前台接待不错 工号1025 服务很好
# --------
# 前台工号0511服务非常不错
# --------------------
#
#
# ---------11180---------
# --------------------
# 酒店干净卫生，前台服务员，1052号非常热情的接待了我。
# --------
# 非常干净卫生的酒店，前台服务员，1097热情的接待了我们。
# --------------------
# --------------------
# 酒店干净卫生，前台服务员，1052号非常热情的接待了我。
# --------
# 酒店非常干净舒适，前台服务员0998热情的接待了我们。
# --------------------
#
#
# ---------11181---------
#
#
# ---------11182---------
#
#
# ---------11183---------
# --------------------
# 环境好服务态度好，方便出行，998
# --------
# 环境优美，服务态度好，出行方便998
# --------------------
#
#
# ---------11184---------
#
#
# ---------11185---------
#
#
# ---------11186---------
# ---------11187---------
# --------------------
# 1107服务好
# --------
# 前台3107 3261服务非常好
# --------------------
# --------------------
# 1107服务好
# --------
# 3107和3621服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 3107和3261服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 前台3035和3261服务好好
# --------------------
# --------------------
# 1107服务好
# --------
# 3101和3261服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 工号3107和3261服务很好值得肯定
# --------------------
# --------------------
# 1107服务好
# --------
# 371.309服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.428服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.423服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 371，254服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.254服务态度很好
# --------------------
# --------------------
# 1107服务好
# --------
# 254.371服务好，
# --------------------
# --------------------
# 1107服务好
# --------
# 305.398服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.359服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 305,224服务态度很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.386服务态度很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.386服务态度很好。
# --------------------
# --------------------
# 1107服务好
# --------
# 371.359服务态度很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.359服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 309.386服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 371，359服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.359服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 305:224服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 305.224服务好好
# --------------------
# --------------------
# 1107服务好
# --------
# 386.309服务很好哦
# --------------------
# --------------------
# 1107服务好
# --------
# 305.224服务态度很好
# --------------------
# --------------------
# 1107服务好
# --------
# 371，359服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 254.371服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 371.359服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511 服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 0038服务好，赞
# --------------------
# --------------------
# 1107服务好
# --------
# 0034服务好！
# --------------------
# --------------------
# 1107服务好
# --------
# 工号0511服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 工号0511服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 0164服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 服务很好0511好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务好的
# --------------------
# --------------------
# 1107服务好
# --------
# 0164服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 0511服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 1017服务态度好
# --------------------
# --------------------
# 1107服务好
# --------
# 1022服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 1042.1017号非常好服务
# --------------------
# --------------------
# 1107服务好
# --------
# 1042，1017号非常好服务
# --------------------
# --------------------
# 1107服务好
# --------
# 580服务好
# --------------------
# --------------------
# 1107服务好
# --------
# 3021服务很好
# --------------------
# --------------------
# 1107服务好
# --------
# 1004服务号
# --------------------
# --------------------
# 1107服务好
# --------
# 580服务好
# --------------------
#
#
# ---------11188---------
#
#
# ---------11189---------
#
#
# ---------11190---------
# --------------------
# 位置很好，出行很方便，前台服务态度很好1017
# --------
# 位置很好，出行方便、前台服务态度很好1012
# --------------------
#
#
# ---------11191---------
#
#
# ---------11192---------
#
#
# ---------11193---------
#
#
# ---------11194---------
# --------------------
# 房间大，位置很好
# --------
# 位置好，房间大!
# --------------------
#
#
# ---------11195---------
#
#
# ---------11196---------
# --------------------
# 好好好好好好好好好0971
# --------
# 酒店前台很好好好好好好好好好好好好0971
# --------------------
# --------------------
# 好好好好好好好好好0971
# --------
# 好啊好啊好好好好好好前台好好971
# --------------------
# --------------------
# 好好好好好好好好好0971
# --------
# 前台3196好好好好好好好
# --------------------
#
#
# ---------11197---------
#
#
# ---------11198---------
#
#
# ---------11199---------
# --------------------
# 前台很好，很不错，推荐入住，很不错，1052
# --------
# 前台很好，很不错，推荐入住1052
# --------------------
# --------------------
# 前台很好，很不错，推荐入住，很不错，1052
# --------
# 很好，很不错，推荐入住， 1052很好
# --------------------
# --------------------
# 前台很好，很不错，推荐入住，很不错，1052
# --------
# 很好，很不错，推荐入住，前台很好1052
# --------------------
# --------------------
# 前台很好，很不错，推荐入住，很不错，1052
# --------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------------------
# --------------------
# 前台很好，很不错，推荐入住，很不错，1052
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11200---------
# --------------------
# 很奈斯，房间很好，很不错，1052超奈斯，推荐入住
# --------
# 很好，很不错，推荐入住， 1052很好
# --------------------
#
#
# ---------11201---------
#
#
# ---------11202---------
# --------------------
# 前台很好，超级热情，推荐入住。奈斯1052
# --------
# 前台服务好，很热情，推荐入住1052
# --------------------
#
#
# ---------11203---------
#
#
# ---------11204---------
# --------------------
# 工号1052
# --------
# 工号3107和3261棒
# --------------------
# --------------------
# 工号1052
# --------
# 工号3107
# --------------------
# --------------------
# 工号1052
# --------
# 0034工号
# --------------------
# --------------------
# 工号1052
# --------
# 工号0034
# --------------------
#
#
# ---------11205---------
#
#
# ---------11206---------
# --------------------
# 前台很好，很不错，推荐入住1052
# --------
# 很好，很不错，推荐入住， 1052很好
# --------------------
# --------------------
# 前台很好，很不错，推荐入住1052
# --------
# 很好，很不错，推荐入住，前台很好1052
# --------------------
# --------------------
# 前台很好，很不错，推荐入住1052
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11207---------
# --------------------
# 很好，很不错，推荐入住， 1052很好
# --------
# 很好，很不错，推荐入住，前台很好1052
# --------------------
# --------------------
# 很好，很不错，推荐入住， 1052很好
# --------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------------------
#
#
# ---------11208---------
#
#
# ---------11209---------
#
#
# ---------11210---------
#
#
# ---------11211---------
# --------------------
# 前台工号998和971的服务态度很好，很满意
# --------
# 服务员（3196号）。她的态度很好。
# --------------------
# --------------------
# 前台工号998和971的服务态度很好，很满意
# --------
# 前台工号0164服务态度很好，给5分。
# --------------------
#
#
# ---------11212---------
# --------------------
# 有停车场的
# --------
# 有停车场的
# --------------------
# --------------------
# 有停车场的
# --------
# 有停车场的。
# --------------------
# --------------------
# 有停车场的
# --------
# 停车场有的
# --------------------
#
#
# ---------11213---------
# --------------------
# 位置优越，停车很方便，前台服务态度不错1017
# --------
# 位置优越，停车很方便，前台服务态度不错1017
# --------------------
# --------------------
# 位置优越，停车很方便，前台服务态度不错1017
# --------
# 位置优越，停车很方便，前台服务态度不错1017
# --------------------
#
#
# ---------11214---------
# --------------------
# 位置优越，停车很方便，前台服务态度不错1017
# --------
# 位置优越，停车很方便，前台服务态度不错1017
# --------------------
#
#
# ---------11215---------
#
#
# ---------11216---------
# --------------------
# 酒店前台很好好好好好好好好好好好好0971
# --------
# 好啊好啊好好好好好好前台好好971
# --------------------
# --------------------
# 酒店前台很好好好好好好好好好好好好0971
# --------
# 前台3196好好好好好好好
# --------------------
#
#
# ---------11217---------
#
#
# ---------11218---------
#
#
# ---------11219---------
# --------------------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------------------
# --------------------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11220---------
#
#
# ---------11221---------
# --------------------
# 前台服务很周到，房间也不错，值得入住推荐，1017
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11222---------
# --------------------
# 性价比很高！
# --------
# 性价比挺高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高，
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高，棒
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高！
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比高！
# --------------------
# --------------------
# 性价比很高！
# --------
# 性价比很高
# --------------------
#
#
# ---------11223---------
#
#
# ---------11224---------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务员态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务挺好，阿雅态度特别好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好。
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 阿姨服务态度很好
# --------
# 服务态度很好
# --------------------
#
#
# ---------11225---------
# --------------------
# 不错，帮朋友订的
# --------
# 帮朋友订的，反馈不错
# --------------------
# --------------------
# 不错，帮朋友订的
# --------
# 不错，帮朋友预定的。
# --------------------
# --------------------
# 不错，帮朋友订的
# --------
# 帮朋友订的，反馈不错！
# --------------------
#
#
# ---------11226---------
#
#
# ---------11227---------
# --------------------
# 环境真的不错
# --------
# 环境不错的
# --------------------
# --------------------
# 环境真的不错
# --------
# 环境不错的
# --------------------
# --------------------
# 环境真的不错
# --------
# 环境不错的
# --------------------
#
#
# ---------11228---------
#
#
# ---------11229---------
#
#
# ---------11230---------
# --------------------
# 哈哈哈哈哈哈还好还好哈哈哈0971
# --------
# 哈哈哈哈哈很好很好哈哈哈哈哈哈哈1017
# --------------------
# --------------------
# 哈哈哈哈哈哈还好还好哈哈哈0971
# --------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------------------
# --------------------
# 哈哈哈哈哈哈还好还好哈哈哈0971
# --------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------------------
#
#
# ---------11231---------
# --------------------
# 哈哈哈哈哈很好很好哈哈哈哈哈哈哈1017
# --------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------------------
# --------------------
# 哈哈哈哈哈很好很好哈哈哈哈哈哈哈1017
# --------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------------------
#
#
# ---------11232---------
#
#
# ---------11233---------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 好哈哈哈哈哈哈哈哈h
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
#
#
# ---------11234---------
# --------------------
# 前台和楼面工作人员都很热情周到??
# --------
# 前台和楼面工作人员都很热情周到??
# --------------------
#
#
# ---------11235---------
#
#
# ---------11236---------
# --------------------
# 非常干净卫生的酒店，前台服务员，1097热情的接待了我们。
# --------
# 酒店非常干净舒适，前台服务员0998热情的接待了我们。
# --------------------
#
#
# ---------11237---------
#
#
# ---------11238---------
#
#
# ---------11239---------
#
#
# ---------11240---------
#
#
# ---------11241---------
#
#
# ---------11242---------
#
#
# ---------11243---------
#
#
# ---------11244---------
#
#
# ---------11245---------
#
#
# ---------11246---------
#
#
# ---------11247---------
#
#
# ---------11248---------
#
#
# ---------11249---------
# --------------------
# 前台服务很好，很不错。推荐入住971
# --------
# 很好，很不错，推荐入住，前台很好1052
# --------------------
# --------------------
# 前台服务很好，很不错。推荐入住971
# --------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------------------
# --------------------
# 前台服务很好，很不错。推荐入住971
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11250---------
#
#
# ---------11251---------
#
#
# ---------11252---------
#
#
# ---------11253---------
# --------------------
# 很好，很不错，推荐入住，前台很好1052
# --------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------------------
# --------------------
# 很好，很不错，推荐入住，前台很好1052
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11254---------
# --------------------
# 前台服务好，很热情，推荐入住1052
# --------
# 前台服务很好，很热情，经常来，推荐入住，1052
# --------------------
# --------------------
# 前台服务好，很热情，推荐入住1052
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
#
#
# ---------11255---------
#
#
# ---------11256---------
# --------------------
# 性价比很高，交通方便
# --------
# 性价比高，交通方便
# --------------------
# --------------------
# 性价比很高，交通方便
# --------
# 交通方便，性价比高
# --------------------
# --------------------
# 性价比很高，交通方便
# --------
# 交通方便，性价比较高。
# --------------------
# --------------------
# 性价比很高，交通方便
# --------
# 交通方便，性价比高。
# --------------------
# --------------------
# 性价比很高，交通方便
# --------
# 性价比高，交通便利
# --------------------
#
#
# ---------11257---------
#
#
# ---------11258---------
#
#
# ---------11259---------
#
#
# ---------11260---------
#
#
# ---------11261---------
#
#
# ---------11262---------
#
#
# ---------11263---------
# --------------------
# 工作人员都很好很热情
# --------
# 不错 工作人员都很热情
# --------------------
# --------------------
# 工作人员都很好很热情
# --------
# 工作人员服务很好
# --------------------
#
#
# ---------11264---------
# --------------------
# 非常不错的
# --------
# 非常不错。
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常的不错
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常的不错
# --------------------
# --------------------
# 非常不错的
# --------
# 非常的不错
# --------------------
# --------------------
# 非常不错的
# --------
# 非常的不错
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错滴
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错的
# --------------------
# --------------------
# 非常不错的
# --------
# 非常不错。
# --------------------
#
#
# ---------11265---------
#
#
# ---------11266---------
#
#
# ---------11267---------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 好哈哈哈哈哈哈哈哈h
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
# --------------------
# 哈哈哈哈哈哈哈哈哈哈哈哈哈0971
# --------
# 哈哈哈哈哈
# --------------------
#
#
# ---------11268---------
#
#
# ---------11269---------
#
#
# ---------11270---------
#
#
# ---------11271---------
# --------------------
# 好啊好啊好好好好好好前台好好971
# --------
# 前台3196好好好好好好好
# --------------------
#
#
# ---------11272---------
# --------------------
# 酒店服务很好
# --------
# 酒店服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务员服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服務很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店很好，服务员服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务很好！
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 很棒的酒店，服务很好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务好
# --------------------
# --------------------
# 酒店服务很好
# --------
# 酒店服务好
# --------------------
#
#
# ---------11273---------
# --------------------
# 服务很好，环境不错，各方面都不错的酒店1017
# --------
# 前台服务很好，各方面都不错的酒店，1017
# --------------------
#
#
# ---------11274---------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境服务很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境服务都很好！
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度好卫生好环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 酒店环境，服务态度都很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境挺好 服务态度也不错
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境不错，服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 酒店环境很好，服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境很好，服务也很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境不错，服务态度好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境很好，服务员态度很好！
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务很好，环境很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境不错 服务态度也很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好，环境不错
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 酒店环境很不错，服务态度也很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务很好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 好环境，好服务
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 酒店环境好，服务态度又好！
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度好，环境好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境很棒，服务态度也很不错
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境服务都很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度 环境都很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 环境好，服务好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好环境也好
# --------
# 服务态度很好
# --------------------
#
#
# ---------11275---------
#
#
# ---------11276---------
# --------------------
# 很干净住着舒服
# --------
# 很干净。住着也舒服
# --------------------
#
#
# ---------11277---------
#
#
# ---------11278---------
#
#
# ---------11279---------
#
#
# ---------11280---------
# --------------------
# 位置很方便
# --------
# 酒店位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置方便！
# --------------------
# --------------------
# 位置很方便
# --------
# 位置好方便
# --------------------
# --------------------
# 位置很方便
# --------
# 酒店位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很好很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 酒店位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很方便
# --------------------
# --------------------
# 位置很方便
# --------
# 位置很方便
# --------------------
#
#
# ---------11281---------
# --------------------
# 服务很好很好，价格比较优惠，值得一住1017
# --------
# 服务很好很好，价格比较优惠，值得一住，1017
# --------------------
#
#
# ---------11282---------
#
#
# ---------11283---------
#
#
# ---------11284---------
#
#
# ---------11285---------
# --------------------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------
# 前台服务很不错，推荐入住，很好1052
# --------------------
# --------------------
# 很好，很不错，推荐入住，服务很好，前台真的很棒1052.很不错971
# --------
# 0164很好，服务很不错。
# --------------------
#
#
# ---------11286---------
#
#
# ---------11287---------
#
#
# ---------11288---------
#
#
# ---------11289---------
#
#
# ---------11290---------
#
#
# ---------11291---------
#
#
# ---------11292---------
# --------------------
# 很好的服务，前台不错，很可以，小姐姐都不错1017
# --------
# 很好的服务，前台不错，很可以，小姐姐都不错1052
# --------------------
#
#
# ---------11293---------
#
#
# ---------11294---------
#
#
# ---------11295---------
#
#
# ---------11296---------
#
#
# ---------11297---------
#
#
# ---------11298---------
#
#
# ---------11299---------
# --------------------
# 1005.性价比可以，房间还不错，很好很好很好
# --------
# 1017。 性价比可以，房间还不错，很好很好很 好
# --------------------
# --------------------
# 1005.性价比可以，房间还不错，很好很好很好
# --------
# 1017。 性价比可以，房间还不错，很好很好很好
# --------------------
#
#
# ---------11300---------
# --------------------
# 1017。 性价比可以，房间还不错，很好很好很 好
# --------
# 1017。 性价比可以，房间还不错，很好很好很好
# --------------------
# ---------11301---------
#
#
# ---------11302---------
#
#
# ---------11303---------
# --------------------
# 环境很好，房间干净整洁，前台人员服务热情1017
# --------
# 环境很好，房间干净整洁，前台人员服务热情，1017
# --------------------
#
#
# ---------11304---------
#
#
# ---------11305---------
# --------------------
# 不错啊，很好
# --------
# 很好不错。
# --------------------
# --------------------
# 不错啊，很好
# --------
# 不错，很好
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，不错
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，很不错
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，不错
# --------------------
# --------------------
# 不错啊，很好
# --------
# 好好好，很不错
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，很不错
# --------------------
# --------------------
# 不错啊，很好
# --------
# 好德很，不错！
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，不错！
# --------------------
# --------------------
# 不错啊，很好
# --------
# 很好，不错。
# --------------------
#
#
# ---------11306---------
#
#
# ---------11307---------
# --------------------
# 商旅两相宜，性价比高，1052小姐姐很热情周到，楼面服务员都挺好
# --------
# 商旅两相宜，性价比高，1052小姐姐很热情周到，楼面服务员都挺好
# --------------------
#
#
# ---------11308---------
#
#
# ---------11309---------
#
#
# ---------11310---------
# --------------------
# 还可以挺好的
# --------
# 还可以 挺好的
# --------------------
#
#
# ---------11311---------
#
#
# ---------11312---------
#
#
# ---------11313---------
#
#
# ---------11314---------
#
#
# ---------11315---------
#
#
# ---------11316---------
#
#
# ---------11317---------
#
#
# ---------11318---------
#
#
# ---------11319---------
# --------------------
# 非常好的酒店
# --------
# 非常棒的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店！
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常棒的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常棒的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店！
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好。
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的連鎖酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
#
#
# ---------11320---------
#
#
# ---------11321---------
#
#
# ---------11322---------
#
#
# ---------11323---------
#
#
# ---------11324---------
#
#
# ---------11325---------
#
#
# ---------11326---------
#
#
# ---------11327---------
#
#
# ---------11328---------
#
#
# ---------11329---------
#
#
# ---------11330---------
#
#
# ---------11331---------
#
#
# ---------11332---------
#
#
# ---------11333---------
#
#
# ---------11334---------
#
#
# ---------11335---------
#
#
# ---------11336---------
#
#
# ---------11337---------
#
#
# ---------11338---------
# --------------------
# 酒店环境挺好
# --------
# 酒店环境很好
# --------------------
# --------------------
# 酒店环境挺好
# --------
# 酒店环境很好！
# --------------------
# --------------------
# 酒店环境挺好
# --------
# 酒店环境很好
# --------------------
# --------------------
# 酒店环境挺好
# --------
# 酒店环境好
# --------------------
#
#
# ---------11339---------
#
#
# ---------11340---------
# --------------------
# 挺好的，不错
# --------
# 不错！挺好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错挺好的！
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，还不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 蛮好的，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，不错！
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错，很好
# --------------------
# --------------------
# 挺好的，不错
# --------
# 还不错，挺好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 很好，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 还不错，挺好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错，挺好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错，挺好的！
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的好，不错，
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的 不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 挺好的，不错的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 很好，不错
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错，蛮好的
# --------------------
# --------------------
# 挺好的，不错
# --------
# 不错挺好的不错挺好的
# --------------------
#
#
# ---------11341---------
#
#
# ---------11342---------
#
#
# ---------11343---------
#
#
# ---------11344---------
#
#
# ---------11345---------
#
#
# ---------11346---------
#
#
# ---------11347---------
# --------------------
# 服务态度很好
# --------
# 服务员态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务挺好，阿雅态度特别好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好呀
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好不
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 挺好！服务员态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好呀
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 环境很好，服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台徐秋琳服务态度很好！
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好。
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 非常好服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 前台服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好美金
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度非常好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度 环境都很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度很好
# --------
# 服务态度很好
# --------------------
#
#
# ---------11348---------
# --------------------
# 地理位置好
# --------
# 地理位置很好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置挺好找
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置很好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
#
#
# ---------11349---------
#
#
# ---------11350---------
#
#
# ---------11351---------
# --------------------
# 环境挺好不错
# --------
# 环境不错，很好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错。
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境不错，很好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 挺不错的环境
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境不错呀
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境，挺不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很好很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 挺不错。环境很好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境好好不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境不错，好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境挺不错的
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 不错，环境很好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境挺不错的
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境挺不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 不错，环境很好
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境很不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 挺好的环境不错
# --------------------
# --------------------
# 环境挺好不错
# --------
# 环境不错啊
# --------------------
# --------------------
# 环境挺好不错
# --------
# 挺好的，环境不错
# --------------------
#
#
# ---------11352---------
#
#
# ---------11353---------
#
#
# ---------11354---------
#
#
# ---------11355---------
#
#
# ---------11356---------
#
#
# ---------11357---------
#
#
# ---------11358---------
#
#
# ---------11359---------
#
#
# ---------11360---------
#
#
# ---------11361---------
# --------------------
# 还不错，性价比高
# --------
# 不错 性价比高
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 酒店不错，性价比高
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 还不错，性价比高
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 还不错，性价比高！
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 还不错，性价比高
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 还不错，性价比挺高的
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 性价比高，不错
# --------------------
# --------------------
# 还不错，性价比高
# --------
# 不错，性价比高
# --------------------
#
#
# ---------11362---------
#
#
# ---------11363---------
#
#
# ---------11364---------
#
#
# ---------11365---------
# --------------------
# A really nice place with good service
# --------
# A little bit of a walk to my office but during the expo the price was OK and the hotel itself is nice. I liked the breakfast a lot and their gym and pool were both great ways to relax when not at the office.
# --------------------
# --------------------
# A really nice place with good service
# --------
# I stay 2 nights with my family , they have very bad parking service i saw it ever every time you want to go out of hotel you should to go and ask him to make the fee are free , even one day i want to go out i ask the reception guy about it and he start to get information from me about my name and my room name then he said is not my business you should to go other counter , I don't know why he spend all this time with 10 of questions when is not his business ?!!! When you have a car is very bad recommend to stay on this kind of hotel
# --------------------
# --------------------
# A really nice place with good service
# --------
# 酒店厕所的镜子有个非常让人怀疑的地方。早上6点起来上厕所看到发红的点，询问了酒店方。给出的回答是厕所电视，我不明白谁会在厕所的镜子里看电视，并且电视位置非常低。这是让人刷牙洗脸低头看电视的意思吗？整个镜子是封闭的非常严实，不打破是不可能知道里面到底是什么。当然酒店经理的辟谣是他们是国际性酒店，现代化，国际化，并解释他们家每个厕所都是这样的，最后也提到了他们是国际大品牌不可能对消费者作出不利的事。 The mirror in the hotel restroom has a very suspicious aspect. I got up at 6 am to go for a pee. I saw the red spot and asked the hotel. The answer is restroom TV. I don't know who watches TV in the bathroom mirror, and it's very low. Is this the meaning that lets customers wash their face to and watch TV? The mirror is so soild that it's impossible to know what's inside without breaking it. Of course, the hotel manager refuted the rumor that they are an international hotel, modern and international, and explained that every restroom in their room is like this, and finally mentioned that they are international brand and cannot do any harm to consumers.
# --------------------
# --------------------
# A really nice place with good service
# --------
# adelabeckyselinabibber 这几个服务太棒了 酒店很好
# --------------------
# --------------------
# A really nice place with good service
# --------
# Good!
# --------------------
# --------------------
# A really nice place with good service
# --------
# room condition is very good and location is very convenient. but the quality of rooms service is not good and breakfast is as well.
# --------------------
# --------------------
# A really nice place with good service
# --------
# Convenient for the flight traveling Service is okay. Very disappointed is the spaghetti in the cafe this time is too salty. Overall the hotel is good.
# --------------------
# --------------------
# A really nice place with good service
# --------
# Very convenience for my early flight. If you want a stay in a hotel that is up to the standard. Pullman is a good option.
# --------------------
# --------------------
# A really nice place with good service
# --------
# Perfect hotel and location! Walking distance to the main sites
# --------------------
# --------------------
# A really nice place with good service
# --------
# toujours trs professionnel
# --------------------
# --------------------
# A really nice place with good service
# --------
# ...
#
#
# ---------12260---------
#
#
# ---------12261---------
#
#
# ---------12262---------
#
#
# ---------12263---------
#
#
# ---------12264---------
#
#
# ---------12265---------
#
#
# ---------12266---------
#
#
# ---------12267---------
#
#
# ---------12268---------
#
#
# ---------12269---------
#
#
# ---------12270---------
#
#
# ---------12271---------
#
#
# ---------12272---------
#
#
# ---------12273---------
#
#
# ---------12274---------
#
#
# ---------12275---------
#
#
# ---------12276---------
#
#
# ---------12277---------
#
#
# ---------12278---------
#
#
# ---------12279---------
#
#
# ---------12280---------
#
#
# ---------12281---------
#
#
# ---------12282---------
#
#
# ---------12283---------
#
#
# ---------12284---------
#
#
# ---------12285---------
#
#
# ---------12286---------
#
#
# ---------12287---------
#
#
# ---------12288---------
#
#
# ---------12289---------
# --------------------
# 早餐不错
# --------
# 早餐不错；
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐不错哦
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐不错哦
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐挺不错
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐还不错
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐很不错
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐不错啊
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐还不错
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐不错。
# --------------------
# --------------------
# 早餐不错
# --------
# 早餐挺不错的
# --------------------
#
#
# ---------12290---------
#
#
# ---------12291---------
# --------------------
# 早餐非常好！
# --------
# 早餐非常好
# --------------------
# --------------------
# 早餐非常好！
# --------
# 早餐非常好
# --------------------
#
#
# ---------12292---------
#
#
# ---------12293---------
#
#
# ---------12294---------
# --------------------
# 酒店设施挺好的！
# --------
# 酒店设施很好
# --------------------
# --------------------
# 酒店设施挺好的！
# --------
# 酒店设施很好
# --------------------
#
#
# ---------12295---------
#
#
# ---------12296---------
#
#
# ---------12297---------
#
#
# ---------12298---------
#
#
# ---------12299---------
#
#
# ---------12300---------
# --------------------
# 交通方便早餐丰富
# --------
# 交通便利，早餐种类丰富
# --------------------
# --------------------
# 交通方便早餐丰富
# --------
# 早餐丰富，交通方便。
# --------------------
#
#
# ---------12301---------
#
#
# ---------12302---------
# --------------------
# 自助餐好像不错
# --------
# 自助餐不错
# --------------------
#
#
# ---------12303---------
#
#
# ---------12304---------
#
#
# ---------12305---------
#
#
# ---------12306---------
#
#
# ---------12307---------
#
#
# ---------12308---------
#
#
# ---------12309---------
#
#
# ---------12310---------
#
#
# ---------12311---------
# --------------------
# 服务好设施新
# --------
# 服务好，设施也新
# --------------------
# --------------------
# 服务好设施新
# --------
# 设施服务很好
# --------------------
# --------------------
# 服务好设施新
# --------
# 服务好，设施新
# --------------------
#
#
# ---------12312---------
#
#
# ---------12313---------
#
#
# ---------12314---------
#
#
# ---------12315---------
# --------------------
# 还不错！！
# --------
# 还不错！！
# --------------------
# --------------------
# 还不错！！
# --------
# 还不错 ！！
# --------------------
# --------------------
# 还不错！！
# --------
# 还不错哦！
# --------------------
#
#
# ---------12316---------
# --------------------
# 还不错！！
# --------
# 还不错 ！！
# --------------------
# --------------------
# 还不错！！
# --------
# 还不错哦！
# --------------------
#
#
# ---------12317---------
#
#
# ---------12318---------
#
#
# ---------12319---------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务质量好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务态度好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务态度很好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美服务态度好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务周到
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 前台服务好，环境优美！
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，态度好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务态度很好
# --------------------
# --------------------
# 环境优美，服务好
# --------
# 环境优美，服务一流
# --------------------
#
#
# ---------12320---------
#
#
# ---------12321---------
#
#
# ---------12322---------
# --------------------
# 还算可以吧
# --------
# 嗯还可以吧
# --------------------
# --------------------
# 还算可以吧
# --------
# 还算可以吧
# --------------------
# --------------------
# 还算可以吧
# --------
# 还可以吧恩
# --------------------
#
#
# ---------12323---------
#
#
# ---------12324---------
#
#
# ---------12325---------
#
#
# ---------12326---------
#
#
# ---------12327---------
#
#
# ---------12328---------
#
#
# ---------12329---------
# --------------------
# 不错 环境干净整洁卫生 服务态度很好...............................
# --------
# 好好好好...........................
# --------------------
#
#
# ---------12330---------
# --------------------
# 很不错，价格不高，地理位置非常好！方便
# --------
# 酒店地理位置不错，很方便，性价比很高。
# --------------------
#
#
# ---------12331---------
#
#
# ---------12332---------
# --------------------
# 非常好！！！
# --------
# 非常棒！！
# --------------------
#
#
# ---------12333---------
# --------------------
# 酒店位置优越
# --------
# 酒店地理位置优越
# --------------------
# --------------------
# 酒店位置优越
# --------
# 酒店位置优越
# --------------------
#
#
# ---------12334---------
# --------------------
# 位置非常好
# --------
# 位置非常好
# --------------------
# --------------------
# 位置非常好
# --------
# 非常好，位置好
# --------------------
# --------------------
# 位置非常好
# --------
# 位置非常好
# --------------------
# --------------------
# 位置非常好
# --------
# 酒店位置非常好
# --------------------
# --------------------
# 位置非常好
# --------
# 位置非常好
# --------------------
# --------------------
# 位置非常好
# --------
# 位置非常好。
# --------------------
# --------------------
# 位置非常好
# --------
# 位置非常好
# --------------------
# --------------------
# 位置非常好
# --------
# 位置非常好
# --------------------
#
#
# ---------12335---------
#
#
# ---------12336---------
#
#
# ---------12337---------
#
#
# ---------12338---------
#
#
# ---------12339---------
#
#
# ---------12340---------
#
#
# ---------12341---------
#
#
# ---------12342---------
# --------------------
# 地理位置好
# --------
# 地理位置好好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置挺好找
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置很好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
# --------------------
# 地理位置好
# --------
# 地理位置好
# --------------------
#
#
# ---------12343---------
# --------------------
# 服务卫生都很好
# --------
# 服务很好干净卫生
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 干净卫生，服务态度很好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好，卫生
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务很好，卫生赶紧
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生好
# --------------------
# --------------------
# 服务卫生都很好
# --------
# 服务好卫生
# --------------------
#
#
# ---------12344---------
# --------------------
# 好，性价比超高！
# --------
# 性价比很高，棒
# --------------------
#
#
# ---------12345---------
#
#
# ---------12346---------
#
#
# ---------12347---------
#
#
# ---------12348---------
#
#
# ---------12349---------
#
#
# ---------12350---------
# --------------------
# 一直住这里。
# --------
# 一直是住这里
# --------------------
#
#
# ---------12351---------
#
#
# ---------12352---------
#
#
# ---------12353---------
#
#
# ---------12354---------
#
#
# ---------12355---------
#
#
# ---------12356---------
#
#
# ---------12357---------
# --------------------
# 环境不错，很安静。
# --------
# 环境挺好的，安静
# --------------------
# --------------------
# 环境不错，很安静。
# --------
# 环境还不错，安静
# --------------------
#
#
# ---------12358---------
#
#
# ---------12359---------
#
#
# ---------12360---------
#
#
# ---------12361---------
#
#
# ---------12362---------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# 酒店非常不错??????????????????????????????????????????????????????????????????????????????????????????????????????????????????
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# ??? ?? Terminal1?? ?? ??? ??? 3??? ???? ????. ??? ?? ???? ?? ???.
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# 酒店不错，会经常回来的！=((( ????)动感光波哔哔哔!!!??????*??*??????-??-??????*??*?-??-?
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# ?????? ?? ??? ????? ? ??? ???? ??? ?? ? ?????. ??? ??? ?? ?? ????? ???? ?? ?????.
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# ??? ??? ?? ????^^ ?? ?? ???? ???? ?????.3??? ? ??? ?? ??? ?? ?????^^
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# 好(? ??_??)?
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# ?? ??? ???? ?? ????????. ??????? ??? ???? ?????. ????.
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# 挺好的，还送了早餐??????????????????????????????????????????????
# --------------------
# --------------------
# ?? ??? ?? ??? ?? ?? ?? ??? ??? ??? ?? ????. ??? ???? ?? ?? ?? ??? ??? ??? ?? ?? ?? ????. ? ??? ??? ??? ????. ?????? ??? ?????? ?? ??? ?? 10? ??? ????? ?? ???? ????
# --------
# 不错??????
# --------------------
#
#
# ---------12363---------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 好酒店，位置棒
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好！
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好
# --------------------
# --------------------
# 酒店位置好
# --------
# 酒店位置很好哦
# --------------------
#
#
# ---------12364---------
#
#
# ---------12365---------
#
#
# ---------12366---------
#
#
# ---------12367---------
#
#
# ---------12368---------
# --------------------
# 交通非常方便，周围都是金融机构，非常适合出差办事居住，酒店配套齐全，床很舒服，早餐很丰富。晚上景观无敌了
# --------
# 交通非常方便，周围都是金融机构，非常适合出差办事居住，酒店配套齐全，床很舒服，早餐很丰富。就是周围有个酒吧，晚上有点吵。
# --------------------
#
#
# ---------12369---------
#
#
# ---------12370---------
#
#
# ---------12371---------
#
#
# ---------12372---------
#
#
# ---------12373---------
# --------------------
# 服务超级棒
# --------
# 服务超级爆
# --------------------
#
#
# ---------12374---------
#
#
# ---------12375---------
#
#
# ---------12376---------
#
#
# ---------12377---------
# --------------------
# 酒店不错很方便
# --------
# 不错的酒店，很方便
# --------------------
#
#
# ---------12378---------
#
#
# ---------12379---------
#
#
# ---------12380---------
#
#
# ---------12381---------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好不
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度不错的
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度不错
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好。
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好。
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务员态度不好。
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度不好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
# --------------------
# 服务态度不好
# --------
# 服务态度很好
# --------------------
#
#
# ---------12382---------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店！
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常棒的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常棒的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店！
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好。
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的連鎖酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 非常好的酒店
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
# --------------------
# 非常好的酒店
# --------
# 酒店非常好
# --------------------
#
#
# ---------12383---------
#
#
# ---------12384---------
#
#
# ---------12385---------
# --------------------
# 设施有点旧
# --------
# 设施有点老旧
# --------------------
# --------------------
# 设施有点旧
# --------
# 设施有点老旧了
# --------------------
# --------------------
# 设施有点旧
# --------
# 设备有点旧
# --------------------
# --------------------
# 设施有点旧
# --------
# 设施有点陈旧
# --------------------
# --------------------
# 设施有点旧
# --------
# 设施有点旧
# --------------------
#
#
# ---------12386---------
# --------------------
# 方便，干净，就就是有点贵
# --------
# 方便，干净，就是有点贵
# --------------------
#
#
# ---------12387---------
# --------------------
# 服务很棒哦
# --------
# 服务很棒！
# --------------------
#
#
# ---------12388---------
