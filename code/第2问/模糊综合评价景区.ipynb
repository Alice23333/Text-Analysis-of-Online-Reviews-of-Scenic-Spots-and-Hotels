# %%
import pandas as pd
import numpy as np

# %%
#result_path_u1 = 'E:/泰迪杯/数据挖掘2021/模糊综合评价结果/有缺失值/模糊综合评价景区评分utf-8.csv'
#result_path_g1 = 'E:/泰迪杯/数据挖掘2021/模糊综合评价结果/有缺失值/模糊综合评价景区评分gbk.csv'
result_path_u = 'E:/泰迪杯/数据挖掘2021/模糊综合评价结果/模糊综合评价景区评分utf-8.csv'
result_path_g = 'E:/泰迪杯/数据挖掘2021/模糊综合评价结果/模糊综合评价景区评分gbk.csv'

# %%
col = ['序号','景区名称','总得分','服务得分','位置得分','设施得分','卫生得分','性价比得分']
rating = pd.DataFrame(columns=col)
for doc_num in range(1,51):
    # 读入数据
    review_path = 'E:/泰迪杯/数据挖掘2021/情感分析结果utf-8/A' + str(doc_num) + 'utf-8.csv'
    reviews = pd.read_csv(review_path, encoding='utf-8')[['评价方面','情感等级']]
    col = {'评价方面':'topic','情感等级':'emotion_level'}
    reviews.rename(columns=col,inplace=True)
    
    # 行名是主题，列名是情感等级，数值是频数
    R_tmp = np.empty(shape=(0,5))
    order = ['服务','位置','设施','卫生','性价比']
    for emotionLevel in range(1,6):
        # 情感等级为emotionLevel的数据表
        level = reviews[reviews['emotion_level'] == emotionLevel]
        print('level ',level)
    
        # 提取在该情感等级下每个评价方面的数量，为向量
        num_arr = level['topic'].value_counts()
        if len(num_arr)>0:
            num_arr = num_arr.reindex(order) # 统一主题顺序为order
            num_arr = num_arr.values
        if len(num_arr)==0: # 向量长度为0
            num_arr = np.zeros((1,5))
    
        # 将向量合并到R中
        R_tmp = np.vstack((R_tmp, num_arr))
    R_tmp = R_tmp.T
    np.nan_to_num(R_tmp, copy=False)  # 将缺失值填充为0
    
    # 计算主题的评价次数
    c = np.array([1,1,1,1,1]).reshape(5,1)
    topic_sum = R_tmp.dot(c)
    
    # 计算评判矩阵R
    R = R_tmp/topic_sum
    print("R = ",R)
    
    # 计算各评价方面的权重矩阵A
    A = (topic_sum/sum(topic_sum)).T
    print("A = ",A)
    
    # 计算模糊综合评价集B
    B = A.dot(R)
    print("B = ",B)
        
    df = {'序号':doc_num, '景区名称':'A'+str(doc_num)}
    level = np.array((5,4,3,2,1))
    df['总得分'] = np.round(level.dot(B.T),1)[0]    # 计算总体满意度
    df['服务得分'] = np.round(level.dot(R[0].T),1)  # 计算服务满意度
    df['位置得分'] = np.round(level.dot(R[1].T),1)  # 计算位置满意度
    df['设施得分'] = np.round(level.dot(R[2].T),1)  # 计算设施满意度
    df['卫生得分'] = np.round(level.dot(R[3].T),1)  # 计算卫生满意度
    df['性价比得分'] = np.round(level.dot(R[4].T),1)  # 计算性价比满意度
    
    rating = rating.append(df,ignore_index=True)
# Out:
# level       topic  emotion_level
# 4       服务              1
# 6       设施              1
# 9      性价比              1
# 11      设施              1
# 14     性价比              1
# ...    ...            ...
# 4571    位置              1
# 4572    位置              1
# 4576   性价比              1
# 4577    服务              1
# 4579   性价比              1
#
# [845 rows x 2 columns]
# level       topic  emotion_level
# 18      服务              2
# 19      设施              2
# 22      设施              2
# 23      位置              2
# 28      设施              2
# ...    ...            ...
# 4582    服务              2
# 4583    服务              2
# 4587    设施              2
# 4589    设施              2
# 4591   性价比              2
#
# [1395 rows x 2 columns]
# level       topic  emotion_level
# 1       服务              3
# 5      性价比              3
# 13      服务              3
# 16      服务              3
# 20     性价比              3
# ...    ...            ...
# 4555    位置              3
# 4566    服务              3
# 4574    服务              3
# 4580    服务              3
# 4588    设施              3
#
# [1194 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              4
# 3       服务              4
# 21      服务              4
# 24      服务              4
# 31      设施              4
# ...    ...            ...
# 4543    服务              4
# 4546    设施              4
# 4561    设施              4
# 4565    设施              4
# 4585   性价比              4
#
# [625 rows x 2 columns]
# level       topic  emotion_level
# 2      性价比              5
# 7       设施              5
# 8      性价比              5
# 10      设施              5
# 12     性价比              5
# ...    ...            ...
# 4584   性价比              5
# 4586   性价比              5
# 4590    服务              5
# 4592    设施              5
# 4593    设施              5
#
# [535 rows x 2 columns]
# R =  [[0.21327801 0.24979253 0.30871369 0.1219917  0.10622407]
#  [0.11634349 0.32686981 0.26315789 0.17451524 0.11911357]
#  [0.21637427 0.31643925 0.22157245 0.12670565 0.11890838]
#  [0.04651163 0.34011628 0.17151163 0.24127907 0.2005814 ]
#  [0.1720524  0.32489083 0.28558952 0.11965066 0.09781659]]
# A =  [[0.26229865 0.07858076 0.33500218 0.07488028 0.24923814]]
# B =  [[0.18393557 0.30365694 0.25990422 0.13604702 0.11645625]]
# level       topic  emotion_level
# 0       设施              1
# 2      性价比              1
# 3      性价比              1
# 8       服务              1
# 10      设施              1
# ...    ...            ...
# 4382    服务              1
# 4385    服务              1
# 4386    设施              1
# 4393    设施              1
# 4395    服务              1
#
# [724 rows x 2 columns]
# level       topic  emotion_level
# 1       卫生              2
# 6       设施              2
# 13      位置              2
# 15      卫生              2
# 19      设施              2
# ...    ...            ...
# 4380    位置              2
# 4383    服务              2
# 4387   性价比              2
# 4391   性价比              2
# 4392    设施              2
#
# [1329 rows x 2 columns]
# level       topic  emotion_level
# 5      性价比              3
# 9       设施              3
# 18     性价比              3
# 45      设施              3
# 47      服务              3
# ...    ...            ...
# 4370    设施              3
# 4377    服务              3
# 4381    服务              3
# 4389    设施              3
# 4390    服务              3
#
# [1220 rows x 2 columns]
# level       topic  emotion_level
# 14     性价比              4
# 16      设施              4
# 17     性价比              4
# 25      设施              4
# 29      服务              4
# ...    ...            ...
# 4373    服务              4
# 4374    服务              4
# 4384    位置              4
# 4388    位置              4
# 4394    设施              4
#
# [622 rows x 2 columns]
# level       topic  emotion_level
# 4       服务              5
# 7       位置              5
# 11      服务              5
# 22     性价比              5
# 24      服务              5
# ...    ...            ...
# 4361    设施              5
# 4362   性价比              5
# 4366    服务              5
# 4368    设施              5
# 4372    服务              5
#
# [501 rows x 2 columns]
# R =  [[0.18566775 0.28094463 0.27361564 0.14250814 0.11726384]
#  [0.09574468 0.35106383 0.25531915 0.17021277 0.12765957]
#  [0.17884323 0.28843227 0.28006088 0.13546423 0.11719939]
#  [0.06321839 0.37068966 0.1954023  0.20977011 0.16091954]
#  [0.19639066 0.29511677 0.32271762 0.10615711 0.07961783]]
# A =  [[0.27934486 0.12829845 0.2989081  0.07916288 0.21428571]]
# B =  [[0.16469518 0.30232029 0.27752502 0.14149227 0.11396724]]
# level       topic  emotion_level
# 1      性价比              1
# 3       服务              1
# 5       服务              1
# 8       服务              1
# 9       服务              1
# ...    ...            ...
# 3917   性价比              1
# 3927    服务              1
# 3928    服务              1
# 3929    服务              1
# 3938   性价比              1
#
# [555 rows x 2 columns]
# level       topic  emotion_level
# 15      服务              2
# 24      服务              2
# 33      服务              2
# 34     性价比              2
# 55      设施              2
# ...    ...            ...
# 3889    设施              2
# 3896    位置              2
# 3902   性价比              2
# 3904    服务              2
# 3905    设施              2
#
# [246 rows x 2 columns]
# level       topic  emotion_level
# 6       设施              3
# 18     性价比              3
# 23      卫生              3
# 27      服务              3
# 46      设施              3
# ...    ...            ...
# 3925    卫生              3
# 3931   性价比              3
# 3934    设施              3
# 3935    服务              3
# 3936    设施              3
#
# [1367 rows x 2 columns]
# level       topic  emotion_level
# 2       位置              4
# 11      设施              4
# 12      位置              4
# 16      服务              4
# 17     性价比              4
# ...    ...            ...
# 3919    位置              4
# 3923    设施              4
# 3926    设施              4
# 3932    卫生              4
# 3933    卫生              4
#
# [1161 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              5
# 4      性价比              5
# 7       卫生              5
# 10     性价比              5
# 13     性价比              5
# ...    ...            ...
# 3867    位置              5
# 3890    服务              5
# 3909   性价比              5
# 3930    设施              5
# 3937    卫生              5
#
# [610 rows x 2 columns]
# R =  [[0.17597087 0.0631068  0.35436893 0.25242718 0.15412621]
#  [0.05709343 0.03114187 0.39619377 0.35640138 0.15916955]
#  [0.20966184 0.07729469 0.32560386 0.26570048 0.12173913]
#  [0.0263789  0.03357314 0.23980815 0.40767386 0.29256595]
#  [0.13732719 0.07557604 0.37695853 0.27834101 0.13179724]]
# A =  [[0.20919015 0.14673775 0.26275704 0.10586443 0.27545062]]
# B =  [[0.14089871 0.0624524  0.3470424  0.29474486 0.15486164]]
# level       topic  emotion_level
# 83      设施              1
# 101     服务              1
# 116     设施              1
# 119     设施              1
# 123     设施              1
# 159     设施              1
# 242     位置              1
# 247    性价比              1
# 326     设施              1
# 402     设施              1
# 448     设施              1
# 529     服务              1
# 583     服务              1
# 839     服务              1
# 984     服务              1
# 1085    设施              1
# 1413    设施              1
# 1462    服务              1
# 1497    设施              1
# 1548    设施              1
# 1566    服务              1
# 1629    设施              1
# 1905    服务              1
# 1959   性价比              1
# 2002    设施              1
# 2023    服务              1
# 2090    设施              1
# 2116    服务              1
# 2117    设施              1
# 2467    服务              1
# 2553    设施              1
# 2848    设施              1
# 2913   性价比              1
# 3005    设施              1
# 3116    服务              1
# 3443    设施              1
# 3538   性价比              1
# 3564    设施              1
# level       topic  emotion_level
# 0       设施              2
# 8       设施              2
# 14      服务              2
# 17      服务              2
# 21      服务              2
# ...    ...            ...
# 3557    设施              2
# 3558    服务              2
# 3561    设施              2
# 3576    设施              2
# 3585   性价比              2
#
# [656 rows x 2 columns]
# level       topic  emotion_level
# 2       设施              3
# 3       服务              3
# 4       设施              3
# 6       设施              3
# 7       设施              3
# ...    ...            ...
# 3579    设施              3
# 3580   性价比              3
# 3581   性价比              3
# 3582    设施              3
# 3586    位置              3
#
# [1696 rows x 2 columns]
# level       topic  emotion_level
# 1       位置              4
# 5       服务              4
# 12      设施              4
# 15      卫生              4
# 16      设施              4
# ...    ...            ...
# 3567    设施              4
# 3570    卫生              4
# 3572    位置              4
# 3583    设施              4
# 3584    设施              4
#
# [1096 rows x 2 columns]
# level       topic  emotion_level
# 25      服务              5
# 61     性价比              5
# 91      卫生              5
# 97      设施              5
# 125     卫生              5
# ...    ...            ...
# 2921   性价比              5
# 3130    设施              5
# 3273    设施              5
# 3429    设施              5
# 3494    位置              5
#
# [101 rows x 2 columns]
# R =  [[0.0199005  0.18076285 0.52902156 0.25041459 0.0199005 ]
#  [0.00271003 0.08672087 0.47696477 0.40650407 0.02710027]
#  [0.01294698 0.24229346 0.42108508 0.29593095 0.02774353]
#  [0.         0.05076142 0.34010152 0.50761421 0.10152284]
#  [0.00502513 0.14070352 0.56658291 0.2701005  0.01758794]]
# A =  [[0.16810705 0.10287148 0.45218846 0.05492055 0.22191246]]
# B =  [[0.01059381 0.18288263 0.47281851 0.30554781 0.02815723]]
# level       topic  emotion_level
# 15      服务              1
# 17     性价比              1
# 101     服务              1
# 120    性价比              1
# 133     服务              1
# ...    ...            ...
# 3279    位置              1
# 3282   性价比              1
# 3447   性价比              1
# 3460    位置              1
# 3507   性价比              1
#
# [91 rows x 2 columns]
# level       topic  emotion_level
# 20     性价比              2
# 30      服务              2
# 37      位置              2
# 39      服务              2
# 47     性价比              2
# ...    ...            ...
# 3553    服务              2
# 3564    服务              2
# 3565    服务              2
# 3569    设施              2
# 3574   性价比              2
#
# [488 rows x 2 columns]
# level       topic  emotion_level
# 0       设施              3
# 1       服务              3
# 2       设施              3
# 8       卫生              3
# 14      服务              3
# ...    ...            ...
# 3562   性价比              3
# 3567    卫生              3
# 3568    服务              3
# 3571    位置              3
# 3572    服务              3
#
# [2397 rows x 2 columns]
# level       topic  emotion_level
# 3       服务              4
# 4       服务              4
# 5       服务              4
# 6       卫生              4
# 7       卫生              4
# ...    ...            ...
# 3555    服务              4
# 3559    服务              4
# 3566   性价比              4
# 3570    服务              4
# 3575    服务              4
#
# [510 rows x 2 columns]
# level       topic  emotion_level
# 9       服务              5
# 10      卫生              5
# 12      服务              5
# 18     性价比              5
# 35      服务              5
# ...    ...            ...
# 3525    服务              5
# 3527    服务              5
# 3550    服务              5
# 3563   性价比              5
# 3573    卫生              5
#
# [90 rows x 2 columns]
# R =  [[0.02289452 0.13082584 0.64268193 0.17661488 0.02698283]
#  [0.01503759 0.09273183 0.72681704 0.13784461 0.02756892]
#  [0.02803738 0.1728972  0.65576324 0.12461059 0.01869159]
#  [0.01030928 0.05841924 0.6185567  0.25085911 0.06185567]
#  [0.03525955 0.1596474  0.70519099 0.08423115 0.01567091]]
# A =  [[0.34200224 0.11157718 0.1795302  0.08137584 0.28551454]]
# B =  [[0.02544743 0.13646532 0.67030201 0.14261745 0.02516779]]
# level       topic  emotion_level
# 3       服务              1
# 6       服务              1
# 14      服务              1
# 15      服务              1
# 17     性价比              1
# ...    ...            ...
# 3430    设施              1
# 3437    位置              1
# 3444   性价比              1
# 3450   性价比              1
# 3455    服务              1
#
# [416 rows x 2 columns]
# level       topic  emotion_level
# 19      服务              2
# 29     性价比              2
# 117    性价比              2
# 146     服务              2
# 149     服务              2
# ...    ...            ...
# 3385   性价比              2
# 3396    位置              2
# 3407    服务              2
# 3448    服务              2
# 3466   性价比              2
#
# [184 rows x 2 columns]
# level       topic  emotion_level
# 0      性价比              3
# 10      服务              3
# 13      位置              3
# 22      服务              3
# 23      设施              3
# ...    ...            ...
# 3467   性价比              3
# 3470    服务              3
# 3471    服务              3
# 3473    位置              3
# 3474    位置              3
#
# [1471 rows x 2 columns]
# level       topic  emotion_level
# 4       设施              4
# 5      性价比              4
# 7       设施              4
# 9       服务              4
# 12      位置              4
# ...    ...            ...
# 3463    卫生              4
# 3468   性价比              4
# 3469   性价比              4
# 3475    设施              4
# 3476   性价比              4
#
# [969 rows x 2 columns]
# level       topic  emotion_level
# 1       服务              5
# 2       服务              5
# 8      性价比              5
# 11      服务              5
# 18      卫生              5
# ...    ...            ...
# 3461   性价比              5
# 3462    位置              5
# 3464   性价比              5
# 3472   性价比              5
# 3477    服务              5
#
# [438 rows x 2 columns]
# R =  [[0.12289916 0.06302521 0.40756303 0.27521008 0.13130252]
#  [0.07100592 0.0433925  0.42011834 0.30966469 0.15581854]
#  [0.14367816 0.05938697 0.42145594 0.27969349 0.09578544]
#  [0.02857143 0.         0.32       0.44       0.21142857]
#  [0.13842663 0.05370651 0.44931921 0.2473525  0.11119516]]
# A =  [[0.27372053 0.14577343 0.15008626 0.05031627 0.38010351]]
# B =  [[0.11960897 0.05290397 0.42294422 0.2786084  0.12593445]]
# level       topic  emotion_level
# 2       服务              1
# 3       卫生              1
# 6       设施              1
# 12     性价比              1
# 14      服务              1
# ...    ...            ...
# 3184    设施              1
# 3191    服务              1
# 3192    位置              1
# 3211    服务              1
# 3213    服务              1
#
# [421 rows x 2 columns]
# level       topic  emotion_level
# 13      卫生              2
# 16      设施              2
# 27      服务              2
# 30      服务              2
# 32      服务              2
# ...    ...            ...
# 3209    服务              2
# 3210   性价比              2
# 3212    设施              2
# 3217   性价比              2
# 3219    位置              2
#
# [1010 rows x 2 columns]
# level       topic  emotion_level
# 0       设施              3
# 4       服务              3
# 9       位置              3
# 10      服务              3
# 11      卫生              3
# ...    ...            ...
# 3215   性价比              3
# 3216    服务              3
# 3218   性价比              3
# 3220    位置              3
# 3221    服务              3
#
# [1265 rows x 2 columns]
# level       topic  emotion_level
# 7       服务              4
# 19      服务              4
# 20      服务              4
# 31      服务              4
# 39      服务              4
# ...    ...            ...
# 3177    服务              4
# 3179    设施              4
# 3189    设施              4
# 3194   性价比              4
# 3214    服务              4
#
# [378 rows x 2 columns]
# level       topic  emotion_level
# 1       服务              5
# 5       服务              5
# 8      性价比              5
# 15     性价比              5
# 18     性价比              5
# ...    ...            ...
# 3079    位置              5
# 3103    卫生              5
# 3131    位置              5
# 3172    服务              5
# 3187    位置              5
#
# [148 rows x 2 columns]
# R =  [[0.13091922 0.30176416 0.40854225 0.10677809 0.05199629]
#  [0.08051948 0.38441558 0.4        0.11688312 0.01818182]
#  [0.17567568 0.28678679 0.41291291 0.08558559 0.03903904]
#  [0.07424594 0.36426914 0.28538283 0.18561485 0.09048724]
#  [0.15082956 0.28506787 0.41176471 0.12217195 0.03016591]]
# A =  [[0.33426443 0.119491   0.20670391 0.13376785 0.20577281]]
# B =  [[0.13066418 0.31346989 0.39261328 0.11731844 0.0459342 ]]
# level       topic  emotion_level
# 7      性价比              1
# 13     性价比              1
# 15     性价比              1
# 21      服务              1
# 22     性价比              1
# ...    ...            ...
# 2639   性价比              1
# 2642   性价比              1
# 2650    设施              1
# 2652   性价比              1
# 2654    设施              1
#
# [334 rows x 2 columns]
# level  Empty DataFrame
# Columns: [topic, emotion_level]
# Index: []
# level       topic  emotion_level
# 0       设施              3
# 1       卫生              3
# 2       设施              3
# 3       位置              3
# 4       设施              3
# ...    ...            ...
# 2672    设施              3
# 2674    设施              3
# 2675    设施              3
# 2676   性价比              3
# 2677    设施              3
#
# [1988 rows x 2 columns]
# level  Empty DataFrame
# Columns: [topic, emotion_level]
# Index: []
# level       topic  emotion_level
# 16      设施              5
# 19      位置              5
# 20     性价比              5
# 23      服务              5
# 25     性价比              5
# ...    ...            ...
# 2625    设施              5
# 2637   性价比              5
# 2664    设施              5
# 2669   性价比              5
# 2673    位置              5
#
# [356 rows x 2 columns]
# R =  [[0.11521739 0.         0.76956522 0.         0.11521739]
#  [0.05228758 0.         0.7745098  0.         0.17320261]
#  [0.13236715 0.         0.72077295 0.         0.1468599 ]
#  [0.04022989 0.         0.77586207 0.         0.18390805]
#  [0.17211949 0.         0.73399716 0.         0.09388336]]
# A =  [[0.17176998 0.11426438 0.38648245 0.06497386 0.26250934]]
# B =  [[0.12471994 0.         0.74234503 0.         0.13293503]]
# level       topic  emotion_level
# 12     性价比              1
# 16      服务              1
# 17     性价比              1
# 20     性价比              1
# 25      服务              1
# ...    ...            ...
# 2481    设施              1
# 2488    设施              1
# 2500   性价比              1
# 2502    服务              1
# 2509   性价比              1
#
# [346 rows x 2 columns]
# level       topic  emotion_level
# 3       服务              2
# 4      性价比              2
# 5      性价比              2
# 13     性价比              2
# 14      服务              2
# ...    ...            ...
# 2497    卫生              2
# 2503    设施              2
# 2506   性价比              2
# 2507    服务              2
# 2510    服务              2
#
# [760 rows x 2 columns]
# level       topic  emotion_level
# 2       位置              3
# 7      性价比              3
# 11      位置              3
# 15      服务              3
# 29      服务              3
# ...    ...            ...
# 2501    设施              3
# 2504   性价比              3
# 2505   性价比              3
# 2508    设施              3
# 2511   性价比              3
#
# [958 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              4
# 1      性价比              4
# 8       服务              4
# 19      服务              4
# 21      设施              4
# ...    ...            ...
# 2449   性价比              4
# 2462    服务              4
# 2463    服务              4
# 2485   性价比              4
# 2490    服务              4
#
# [295 rows x 2 columns]
# level       topic  emotion_level
# 6      性价比              5
# 9      性价比              5
# 10      卫生              5
# 23     性价比              5
# 26     性价比              5
# ...    ...            ...
# 2396    服务              5
# 2398    位置              5
# 2401    卫生              5
# 2425   性价比              5
# 2437   性价比              5
#
# [153 rows x 2 columns]
# R =  [[0.16806723 0.29831933 0.3627451  0.11344538 0.05742297]
#  [0.08805031 0.30503145 0.4245283  0.13207547 0.05031447]
#  [0.17585302 0.26246719 0.44094488 0.09186352 0.02887139]
#  [0.07307692 0.39230769 0.23846154 0.19615385 0.1       ]
#  [0.13349225 0.29558999 0.39809297 0.10250298 0.07032181]]
# A =  [[0.28423567 0.12659236 0.15167197 0.10350318 0.33399682]]
# B =  [[0.13773885 0.30254777 0.38136943 0.11743631 0.06090764]]
# level       topic  emotion_level
# 1      性价比              1
# 3       服务              1
# 6       服务              1
# 12      服务              1
# 15      设施              1
# ...    ...            ...
# 1806    设施              1
# 1813    服务              1
# 1817   性价比              1
# 1822    位置              1
# 1861   性价比              1
#
# [211 rows x 2 columns]
# level       topic  emotion_level
# 2       设施              2
# 21     性价比              2
# 25      服务              2
# 33     性价比              2
# 50      设施              2
# ...    ...            ...
# 1699   性价比              2
# 1704    设施              2
# 1710    设施              2
# 1746    设施              2
# 1791    设施              2
#
# [114 rows x 2 columns]
# level       topic  emotion_level
# 9       位置              3
# 11     性价比              3
# 13      服务              3
# 16     性价比              3
# 19     性价比              3
# ...    ...            ...
# 1862    设施              3
# 1865   性价比              3
# 1866    设施              3
# 1868    卫生              3
# 1869    服务              3
#
# [670 rows x 2 columns]
# level       topic  emotion_level
# 4       设施              4
# 7       位置              4
# 10      位置              4
# 26      卫生              4
# 27      服务              4
# ...    ...            ...
# 1857    卫生              4
# 1860   性价比              4
# 1863   性价比              4
# 1864    卫生              4
# 1867    卫生              4
#
# [583 rows x 2 columns]
# level       topic  emotion_level
# 0       卫生              5
# 5       位置              5
# 8       设施              5
# 14     性价比              5
# 22      卫生              5
# ...    ...            ...
# 1844    设施              5
# 1850    设施              5
# 1851    服务              5
# 1856    卫生              5
# 1858    设施              5
#
# [292 rows x 2 columns]
# R =  [[0.18315018 0.07326007 0.38827839 0.21978022 0.13553114]
#  [0.07317073 0.03658537 0.39939024 0.34146341 0.14939024]
#  [0.12353923 0.07178631 0.360601   0.30550918 0.13856427]
#  [0.00943396 0.03301887 0.24056604 0.42924528 0.28773585]
#  [0.13318777 0.069869   0.36244541 0.29912664 0.13537118]]
# A =  [[0.1459893  0.17540107 0.32032086 0.11336898 0.24491979]]
# B =  [[0.11283422 0.06096257 0.35828877 0.31176471 0.15614973]]
# level       topic  emotion_level
# 3       位置              1
# 4       设施              1
# 13     性价比              1
# 14      位置              1
# 21     性价比              1
# ...    ...            ...
# 1797    设施              1
# 1798    设施              1
# 1802    服务              1
# 1825   性价比              1
# 1845    卫生              1
#
# [219 rows x 2 columns]
# level       topic  emotion_level
# 1       位置              2
# 9      性价比              2
# 17      服务              2
# 19      卫生              2
# 20     性价比              2
# ...    ...            ...
# 1834    位置              2
# 1835    设施              2
# 1839    服务              2
# 1840    服务              2
# 1851    位置              2
#
# [589 rows x 2 columns]
# level       topic  emotion_level
# 2      性价比              3
# 5       卫生              3
# 6      性价比              3
# 7       位置              3
# 8       位置              3
# ...    ...            ...
# 1846   性价比              3
# 1847    服务              3
# 1848    位置              3
# 1849   性价比              3
# 1850    服务              3
#
# [737 rows x 2 columns]
# level       topic  emotion_level
# 0       设施              4
# 10      卫生              4
# 24     性价比              4
# 25      服务              4
# 42      卫生              4
# ...    ...            ...
# 1819    卫生              4
# 1827    卫生              4
# 1829    位置              4
# 1838    服务              4
# 1842   性价比              4
#
# [216 rows x 2 columns]
# level       topic  emotion_level
# 11     性价比              5
# 22      服务              5
# 35      卫生              5
# 40      位置              5
# 49      卫生              5
# ...    ...            ...
# 1596    服务              5
# 1619    位置              5
# 1683    位置              5
# 1759    卫生              5
# 1801    位置              5
#
# [91 rows x 2 columns]
# R =  [[0.13851351 0.24662162 0.45608108 0.10472973 0.05405405]
#  [0.08091286 0.35062241 0.37966805 0.12448133 0.06431535]
#  [0.12435233 0.28497409 0.47150259 0.08290155 0.03626943]
#  [0.05555556 0.43402778 0.24652778 0.20833333 0.05555556]
#  [0.1875     0.28       0.415      0.0825     0.035     ]]
# A =  [[0.15982721 0.26025918 0.20842333 0.15550756 0.21598272]]
# B =  [[0.11825054 0.31803456 0.39794816 0.11663067 0.04913607]]
# level       topic  emotion_level
# 7      性价比              1
# 8      性价比              1
# 18      服务              1
# 21      服务              1
# 32      服务              1
# ...    ...            ...
# 1095    服务              1
# 1134    服务              1
# 1156    服务              1
# 1277   性价比              1
# 1316    服务              1
#
# [96 rows x 2 columns]
# level       topic  emotion_level
# 2       服务              2
# 6      性价比              2
# 11     性价比              2
# 13     性价比              2
# 14      位置              2
# ...    ...            ...
# 1314   性价比              2
# 1315    卫生              2
# 1319    服务              2
# 1321    位置              2
# 1326    设施              2
#
# [483 rows x 2 columns]
# level       topic  emotion_level
# 1      性价比              3
# 3       服务              3
# 24      设施              3
# 31      服务              3
# 34      设施              3
# ...    ...            ...
# 1322    卫生              3
# 1323    服务              3
# 1325    设施              3
# 1327    设施              3
# 1328    设施              3
#
# [456 rows x 2 columns]
# level       topic  emotion_level
# 4       卫生              4
# 5       设施              4
# 10      服务              4
# 12      卫生              4
# 19      卫生              4
# ...    ...            ...
# 1291    卫生              4
# 1296   性价比              4
# 1297    设施              4
# 1320    卫生              4
# 1324   性价比              4
#
# [190 rows x 2 columns]
# level       topic  emotion_level
# 0      性价比              5
# 9       设施              5
# 15      卫生              5
# 16      卫生              5
# 28     性价比              5
# ...    ...            ...
# 1169    设施              5
# 1180    设施              5
# 1206   性价比              5
# 1216    设施              5
# 1226    卫生              5
#
# [104 rows x 2 columns]
# R =  [[0.12560386 0.28502415 0.43478261 0.08695652 0.06763285]
#  [0.02803738 0.35981308 0.36915888 0.15420561 0.08878505]
#  [0.07037037 0.31481481 0.44074074 0.13333333 0.04074074]
#  [0.06303725 0.44412607 0.1747851  0.20057307 0.11747851]
#  [0.07958478 0.37024221 0.37024221 0.11418685 0.06574394]]
# A =  [[0.15575621 0.16102333 0.20316027 0.26260346 0.21745673]]
# B =  [[0.07223476 0.36343115 0.34311512 0.14296464 0.07825433]]
# level       topic  emotion_level
# 43     性价比              1
# 186    性价比              1
# 226     服务              1
# 249     服务              1
# 307     服务              1
# 319    性价比              1
# 376     服务              1
# 391     设施              1
# 767     设施              1
# 812    性价比              1
# 824     设施              1
# 843    性价比              1
# 844     设施              1
# 855     服务              1
# 862     服务              1
# 873     设施              1
# 907    性价比              1
# 944    性价比              1
# 955     设施              1
# 962     位置              1
# 995     位置              1
# 1036   性价比              1
# 1085   性价比              1
# 1164    服务              1
# level       topic  emotion_level
# 2       服务              2
# 4       服务              2
# 7       服务              2
# 9       服务              2
# 10      卫生              2
# ...    ...            ...
# 1208   性价比              2
# 1209    设施              2
# 1213    卫生              2
# 1216    服务              2
# 1217   性价比              2
#
# [392 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              3
# 1      性价比              3
# 3       服务              3
# 6       服务              3
# 8       服务              3
# ...    ...            ...
# 1210    设施              3
# 1211    服务              3
# 1212    设施              3
# 1214    设施              3
# 1215   性价比              3
#
# [589 rows x 2 columns]
# level       topic  emotion_level
# 15      卫生              4
# 18      服务              4
# 23      服务              4
# 25      服务              4
# 29      服务              4
# ...    ...            ...
# 1167    服务              4
# 1168    服务              4
# 1169    服务              4
# 1183    服务              4
# 1195    服务              4
#
# [172 rows x 2 columns]
# level       topic  emotion_level
# 5       服务              5
# 20      服务              5
# 42      服务              5
# 45      卫生              5
# 57      服务              5
# 69      卫生              5
# 80      卫生              5
# 84      服务              5
# 92      服务              5
# 94      服务              5
# 107     服务              5
# 130     位置              5
# 138     设施              5
# 171     设施              5
# 183     服务              5
# 189     服务              5
# 194     卫生              5
# 213     服务              5
# 241     位置              5
# 248     服务              5
# 253     服务              5
# 275     位置              5
# 320     服务              5
# 351     服务              5
# 381     服务              5
# 399     服务              5
# 410     服务              5
# 450     服务              5
# 457     服务              5
# 483     服务              5
# 522     服务              5
# 815     服务              5
# 828     卫生              5
# 845    性价比              5
# 905    性价比              5
# 925     设施              5
# 952     卫生              5
# 980    性价比              5
# 983     服务              5
# 1043   性价比              5
# 1163    服务              5
# R =  [[0.00912647 0.30899609 0.4589309  0.19035202 0.03259452]
#  [0.02197802 0.28571429 0.58241758 0.07692308 0.03296703]
#  [0.05263158 0.30701754 0.57894737 0.03508772 0.02631579]
#  [0.         0.4140625  0.4609375  0.078125   0.046875  ]
#  [0.07627119 0.34745763 0.5        0.04237288 0.03389831]]
# A =  [[0.62972085 0.07471264 0.09359606 0.10509031 0.09688013]]
# B =  [[0.01970443 0.32183908 0.48357964 0.14121511 0.03366174]]
# level       topic  emotion_level
# 12      服务              1
# 17     性价比              1
# 39     性价比              1
# 41     性价比              1
# 45     性价比              1
# ...    ...            ...
# 1080   性价比              1
# 1099    服务              1
# 1111    位置              1
# 1128    服务              1
# 1130    服务              1
#
# [126 rows x 2 columns]
# level       topic  emotion_level
# 1      性价比              2
# 7       服务              2
# 8       位置              2
# 10      卫生              2
# 11      服务              2
# ...    ...            ...
# 1132   性价比              2
# 1133    服务              2
# 1134   性价比              2
# 1136    服务              2
# 1140    服务              2
#
# [382 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              3
# 5       位置              3
# 6       服务              3
# 9       服务              3
# 14      服务              3
# ...    ...            ...
# 1120   性价比              3
# 1124   性价比              3
# 1127    服务              3
# 1129    服务              3
# 1138    服务              3
#
# [380 rows x 2 columns]
# level       topic  emotion_level
# 3      性价比              4
# 4       位置              4
# 13     性价比              4
# 20      卫生              4
# 28      卫生              4
# ...    ...            ...
# 1093    卫生              4
# 1131    服务              4
# 1135    卫生              4
# 1137    服务              4
# 1139    卫生              4
#
# [163 rows x 2 columns]
# level       topic  emotion_level
# 2      性价比              5
# 16      位置              5
# 18      设施              5
# 19      服务              5
# 27     性价比              5
# ...    ...            ...
# 1015    卫生              5
# 1036    卫生              5
# 1051    服务              5
# 1068    卫生              5
# 1126    卫生              5
#
# [90 rows x 2 columns]
# R =  [[0.1462585  0.27891156 0.34013605 0.15306122 0.08163265]
#  [0.06550218 0.37554585 0.30131004 0.17467249 0.08296943]
#  [0.12598425 0.28346457 0.40944882 0.11811024 0.06299213]
#  [0.03149606 0.46456693 0.18110236 0.18110236 0.14173228]
#  [0.13186813 0.32692308 0.37362637 0.10989011 0.05769231]]
# A =  [[0.25766871 0.20070114 0.11130587 0.11130587 0.3190184 ]]
# B =  [[0.11042945 0.33479404 0.33304119 0.14285714 0.07887818]]
# level       topic  emotion_level
# 8       设施              1
# 12      设施              1
# 17      服务              1
# 19      设施              1
# 28     性价比              1
# ...    ...            ...
# 1045   性价比              1
# 1064   性价比              1
# 1065    服务              1
# 1077   性价比              1
# 1092    设施              1
#
# [139 rows x 2 columns]
# level       topic  emotion_level
# 1       设施              2
# 7       位置              2
# 9       服务              2
# 10      服务              2
# 14      设施              2
# ...    ...            ...
# 1074    位置              2
# 1078    卫生              2
# 1081    位置              2
# 1086    位置              2
# 1094    设施              2
#
# [378 rows x 2 columns]
# level       topic  emotion_level
# 0       服务              3
# 4       服务              3
# 6       设施              3
# 11      设施              3
# 13     性价比              3
# ...    ...            ...
# 1087   性价比              3
# 1089   性价比              3
# 1090   性价比              3
# 1091   性价比              3
# 1093   性价比              3
#
# [370 rows x 2 columns]
# level       topic  emotion_level
# 2       设施              4
# 5       设施              4
# 15      服务              4
# 24     性价比              4
# 38      服务              4
# ...    ...            ...
# 1049    卫生              4
# 1052   性价比              4
# 1059    位置              4
# 1085    设施              4
# 1088    设施              4
#
# [123 rows x 2 columns]
# level       topic  emotion_level
# 3       设施              5
# 22     性价比              5
# 37      服务              5
# 39      设施              5
# 49      设施              5
# ...    ...            ...
# 991     卫生              5
# 995     位置              5
# 1009    卫生              5
# 1011    设施              5
# 1026    卫生              5
#
# [85 rows x 2 columns]
# R =  [[0.14218009 0.32227488 0.4028436  0.09004739 0.04265403]
#  [0.04117647 0.45294118 0.22352941 0.18235294 0.1       ]
#  [0.12885154 0.32212885 0.33053221 0.11764706 0.10084034]
#  [0.04819277 0.39759036 0.27710843 0.12048193 0.15662651]
#  [0.18978102 0.31021898 0.38686131 0.07664234 0.03649635]]
# A =  [[0.19269406 0.15525114 0.3260274  0.07579909 0.25022831]]
# B =  [[0.12694064 0.34520548 0.33789954 0.11232877 0.07762557]]
# level      topic  emotion_level
# 4     性价比              1
# 23    性价比              1
# 27    性价比              1
# 35     服务              1
# 39    性价比              1
# ..    ...            ...
# 938    设施              1
# 945    卫生              1
# 960   性价比              1
# 973   性价比              1
# 986   性价比              1
# [96 rows x 2 columns]
# level      topic  emotion_level
# 1     性价比              2
# 10    性价比              2
# 12     服务              2
# 18    性价比              2
# 25     卫生              2
# ..    ...            ...
# 978    位置              2
# 979    服务              2
# 982   性价比              2
# 983    服务              2
# 984    卫生              2
#
# [312 rows x 2 columns]
# level      topic  emotion_level
# 3      服务              3
# 7      卫生              3
# 9     性价比              3
# 11     卫生              3
# 13     位置              3
# ..    ...            ...
# 969   性价比              3
# 971    服务              3
# 977   性价比              3
# 980    卫生              3
# 985    位置              3
#
# [400 rows x 2 columns]
# level      topic  emotion_level
# 6      服务              4
# 8      位置              4
# 16     服务              4
# 20     服务              4
# 21     服务              4
# ..    ...            ...
# 954    卫生              4
# 964    服务              4
# 965    卫生              4
# 974    卫生              4
# 981    卫生              4
#
# [112 rows x 2 columns]
# level      topic  emotion_level
# 0     性价比              5
# 2      卫生              5
# 5      服务              5
# 14     卫生              5
# 22     卫生              5
# ..    ...            ...
# 921   性价比              5
# 953   性价比              5
# 956    卫生              5
# 970    位置              5
# 976    设施              5
#
# [67 rows x 2 columns]
# R =  [[0.1625     0.225      0.45       0.10625    0.05625   ]
#  [0.05426357 0.37984496 0.43410853 0.09302326 0.03875969]
#  [0.04032258 0.36290323 0.40322581 0.14516129 0.0483871 ]
#  [0.0323741  0.39928058 0.33453237 0.15107914 0.08273381]
#  [0.16554054 0.23986486 0.43581081 0.0777027  0.08108108]]
# A =  [[0.1621074  0.13069909 0.12563323 0.2816616  0.29989868]]
# B =  [[0.09726444 0.31610942 0.40526849 0.11347518 0.06788247]]
# level      topic  emotion_level
# 0      服务              1
# 4     性价比              1
# 9     性价比              1
# 17     设施              1
# 19    性价比              1
# ..    ...            ...
# 940   性价比              1
# 942    位置              1
# 947   性价比              1
# 952    位置              1
# 960   性价比              1
#
# [122 rows x 2 columns]
# level      topic  emotion_level
# 5     性价比              2
# 15     卫生              2
# 18    性价比              2
# 21     服务              2
# 26    性价比              2
# ..    ...            ...
# 961    位置              2
# 963    卫生              2
# 964   性价比              2
# 967    服务              2
# 969    服务              2
#
# [304 rows x 2 columns]
# level      topic  emotion_level
# 6      设施              3
# 7     性价比              3
# 10     设施              3
# 13    性价比              3
# 14     卫生              3
# ..    ...            ...
# 958    服务              3
# 959    位置              3
# 962   性价比              3
# 965   性价比              3
# 966   性价比              3
#
# [371 rows x 2 columns]
# level      topic  emotion_level
# 1     性价比              4
# 3     性价比              4
# 11     设施              4
# 12     卫生              4
# 20     位置              4
# ..    ...            ...
# 894    卫生              4
# 910    服务              4
# 920    设施              4
# 941    设施              4
# 954    服务              4
#
# [110 rows x 2 columns]
# level      topic  emotion_level
# 2     性价比              5
# 8     性价比              5
# 29     服务              5
# 36     位置              5
# 42     位置              5
# ..    ...            ...
# 844   性价比              5
# 848    服务              5
# 851    卫生              5
# 888    服务              5
# 968   性价比              5
#
# [63 rows x 2 columns]
# R =  [[0.14371257 0.28143713 0.41317365 0.06586826 0.09580838]
#  [0.08982036 0.34730539 0.35928144 0.1257485  0.07784431]
#  [0.13970588 0.27205882 0.47058824 0.06617647 0.05147059]
#  [0.04145078 0.37305699 0.32124352 0.19689119 0.06735751]
#  [0.18241042 0.29315961 0.37785016 0.1009772  0.04560261]]
# A =  [[0.17216495 0.17216495 0.14020619 0.19896907 0.31649485]]
# B =  [[0.1257732  0.31340206 0.38247423 0.11340206 0.06494845]]
# level      topic  emotion_level
# 0      服务              1
# 1     性价比              1
# 6      设施              1
# 20     服务              1
# 23    性价比              1
# ..    ...            ...
# 896   性价比              1
# 898    卫生              1
# 899   性价比              1
# 906    服务              1
# 913   性价比              1
#
# [140 rows x 2 columns]
# level      topic  emotion_level
# 4      服务              2
# 9     性价比              2
# 11     服务              2
# 12    性价比              2
# 28     服务              2
# ..    ...            ...
# 903    位置              2
# 904   性价比              2
# 905    服务              2
# 909   性价比              2
# 915   性价比              2
#
# [295 rows x 2 columns]
# level      topic  emotion_level
# 2     性价比              3
# 5      位置              3
# 7     性价比              3
# 16    性价比              3
# 18     位置              3
# ..    ...            ...
# 908    服务              3
# 910    服务              3
# 911   性价比              3
# 912    服务              3
# 914   性价比              3
#
# [284 rows x 2 columns]
# level      topic  emotion_level
# 10     卫生              4
# 13     服务              4
# 17    性价比              4
# 31     服务              4
# 43    性价比              4
# ..    ...            ...
# 807    服务              4
# 831    卫生              4
# 838    服务              4
# 874    服务              4
# 897   性价比              4
#
# [109 rows x 2 columns]
# level      topic  emotion_level
# 3      卫生              5
# 8     性价比              5
# 14     位置              5
# 15     服务              5
# 19     卫生              5
# ..    ...            ...
# 815   性价比              5
# 839   性价比              5
# 844   性价比              5
# 861    位置              5
# 872   性价比              5
#
# [88 rows x 2 columns]
# R =  [[0.1622807  0.30701754 0.38596491 0.10526316 0.03947368]
#  [0.06097561 0.32926829 0.37804878 0.13414634 0.09756098]
#  [0.20382166 0.33121019 0.32484076 0.10191083 0.03821656]
#  [0.10900474 0.33175355 0.2464455  0.13744076 0.17535545]
#  [0.18067227 0.31932773 0.2605042  0.12184874 0.11764706]]
# A =  [[0.2489083  0.08951965 0.17139738 0.23034934 0.25982533]]
# B =  [[0.15283843 0.3220524  0.31004367 0.11899563 0.09606987]]
# level      topic  emotion_level
# 3      设施              1
# 7      设施              1
# 19    性价比              1
# 20    性价比              1
# 33     服务              1
# ..    ...            ...
# 881   性价比              1
# 884    设施              1
# 892   性价比              1
# 897    服务              1
# 913    位置              1
#
# [128 rows x 2 columns]
# level      topic  emotion_level
# 2      卫生              2
# 5      设施              2
# 6      卫生              2
# 8      卫生              2
# 12     卫生              2
# ..    ...            ...
# 896    卫生              2
# 898   性价比              2
# 904    服务              2
# 908    卫生              2
# 912   性价比              2
#
# [288 rows x 2 columns]
# level      topic  emotion_level
# 0      服务              3
# 9      服务              3
# 10    性价比              3
# 11    性价比              3
# 17    性价比              3
# ..    ...            ...
# 907    服务              3
# 909   性价比              3
# 910    设施              3
# 911   性价比              3
# 914   性价比              3
#
# [331 rows x 2 columns]
# level      topic  emotion_level
# 14     设施              4
# 21    性价比              4
# 24     设施              4
# 25     卫生              4
# 29     卫生              4
# ..    ...            ...
# 842    卫生              4
# 854   性价比              4
# 865    卫生              4
# 866    设施              4
# 899    位置              4
#
# [99 rows x 2 columns]
# level      topic  emotion_level
# 1      卫生              5
# 4      卫生              5
# 13     卫生              5
# 22    性价比              5
# 35     设施              5
# ..    ...            ...
# 816    位置              5
# 819    卫生              5
# 848    位置              5
# 850    设施              5
# 887    位置              5
#
# [69 rows x 2 columns]
# R =  [[0.14285714 0.24603175 0.41269841 0.11904762 0.07936508]
#  [0.09821429 0.33928571 0.34821429 0.14285714 0.07142857]
#  [0.12931034 0.25862069 0.5        0.06896552 0.04310345]
#  [0.0862069  0.36206897 0.29655172 0.14482759 0.11034483]
#  [0.21771218 0.3099631  0.35424354 0.06642066 0.05166052]]
# A =  [[0.13770492 0.12240437 0.12677596 0.31693989 0.29617486]]
# B =  [[0.13989071 0.3147541  0.36174863 0.10819672 0.07540984]]
# level      topic  emotion_level
# 5      卫生              1
# 6      服务              1
# 20    性价比              1
# 30    性价比              1
# 34    性价比              1
# ..    ...            ...
# 865    服务              1
# 873   性价比              1
# 878    服务              1
# 882    服务              1
# 892    位置              1
#
# [110 rows x 2 columns]
# level      topic  emotion_level
# 0      服务              2
# 2     性价比              2
# 3      位置              2
# 29     服务              2
# 47    性价比              2
# 56     服务              2
# 59    性价比              2
# 68     位置              2
# 70     服务              2
# 84    性价比              2
# 103    设施              2
# 109   性价比              2
# 124   性价比              2
# 162   性价比              2
# 163   性价比              2
# 185   性价比              2
# 206    位置              2
# 207    设施              2
# 247    卫生              2
# 276    服务              2
# 295   性价比              2
# 296   性价比              2
# 303   性价比              2
# 329    服务              2
# 347    服务              2
# 348    位置              2
# 349    服务              2
# 370    服务              2
# 373    设施              2
# 382    服务              2
# 393    服务              2
# 402   性价比              2
# 408   性价比              2
# 456   性价比              2
# 482   性价比              2
# 495    卫生              2
# 500    服务              2
# 502    卫生              2
# 506   性价比              2
# 519    服务              2
# 529    服务              2
# 533    服务              2
# 637   性价比              2
# 651   性价比              2
# 696   性价比              2
# 721    卫生              2
# 749    位置              2
# 785    设施              2
# 786   性价比              2
# 800    设施              2
# 884    位置              2
# level      topic  emotion_level
# 7      卫生              3
# 9     性价比              3
# 12     服务              3
# 15    性价比              3
# 19     位置              3
# ..    ...            ...
# 888    卫生              3
# 890   性价比              3
# 891    位置              3
# 893    卫生              3
# 894    服务              3
#
# [397 rows x 2 columns]
# level      topic  emotion_level
# 10     服务              4
# 11    性价比              4
# 14     设施              4
# 16    性价比              4
# 17    性价比              4
# ..    ...            ...
# 849    位置              4
# 853    设施              4
# 874    设施              4
# 875    设施              4
# 877    位置              4
#
# [219 rows x 2 columns]
# level      topic  emotion_level
# 1      服务              5
# 4      卫生              5
# 8      服务              5
# 13     卫生              5
# 18    性价比              5
# ..    ...            ...
# 860   性价比              5
# 869   性价比              5
# 880    设施              5
# 881   性价比              5
# 889    服务              5
#
# [118 rows x 2 columns]
# R =  [[0.15763547 0.07389163 0.41871921 0.25123153 0.09852217]
#  [0.1023622  0.04724409 0.43307087 0.25984252 0.15748031]
#  [0.12318841 0.03623188 0.46376812 0.23913043 0.13768116]
#  [0.06       0.04       0.34       0.29       0.27      ]
#  [0.12844037 0.06422018 0.48623853 0.22324159 0.09785933]]
# A =  [[0.22681564 0.14189944 0.15418994 0.11173184 0.36536313]]
# B =  [[0.12290503 0.05698324 0.44357542 0.24469274 0.13184358]]
# level      topic  emotion_level
# 5      服务              1
# 7      服务              1
# 19    性价比              1
# 20     设施              1
# 35    性价比              1
# ..    ...            ...
# 731    卫生              1
# 784   性价比              1
# 795    设施              1
# 820   性价比              1
# 841    卫生              1
#
# [62 rows x 2 columns]
# level      topic  emotion_level
# 1      卫生              2
# 4      卫生              2
# 6      设施              2
# 14     位置              2
# 21    性价比              2
# ..    ...            ...
# 848   性价比              2
# 851    设施              2
# 852   性价比              2
# 854   性价比              2
# 856    服务              2
#
# [275 rows x 2 columns]
# level      topic  emotion_level
# 0      卫生              3
# 8      服务              3
# 17    性价比              3
# 24    性价比              3
# 26     位置              3
# ..    ...            ...
# 845    设施              3
# 846   性价比              3
# 847    设施              3
# 849    卫生              3
# 858    设施              3
#
# [371 rows x 2 columns]
# level      topic  emotion_level
# 2      卫生              4
# 11    性价比              4
# 12    性价比              4
# 13     卫生              4
# 15     卫生              4
# ..    ...            ...
# 833    卫生              4
# 836    服务              4
# 850    服务              4
# 855   性价比              4
# 857   性价比              4
#
# [97 rows x 2 columns]
# level      topic  emotion_level
# 3     性价比              5
# 9     性价比              5
# 10     卫生              5
# 18    性价比              5
# 28     服务              5
# 29     卫生              5
# 38     设施              5
# 40     卫生              5
# 43    性价比              5
# 46     卫生              5
# 52     设施              5
# 55     设施              5
# 60    性价比              5
# 66     服务              5
# 71     位置              5
# 94     设施              5
# 112   性价比              5
# 126    服务              5
# 145    卫生              5
# 146    位置              5
# 152   性价比              5
# 158    设施              5
# 171    服务              5
# 206    卫生              5
# 241    服务              5
# 243    卫生              5
# 256    服务              5
# 267    卫生              5
# 275    服务              5
# 294    服务              5
# 299    卫生              5
# 319    卫生              5
# 328    设施              5
# 332    卫生              5
# 348    位置              5
# 368    设施              5
# 390    位置              5
# 396    设施              5
# 401    服务              5
# 406    卫生              5
# 476    服务              5
# 493    位置              5
# 542    卫生              5
# 555    卫生              5
# 579    设施              5
# 582    服务              5
# 604    设施              5
# 605    卫生              5
# 714    卫生              5
# 773    卫生              5
# 781    服务              5
# 798    位置              5
# 809   性价比              5
# 853    服务              5
# R =  [[0.11392405 0.25316456 0.44936709 0.10126582 0.08227848]
#  [0.02419355 0.37903226 0.41129032 0.13709677 0.0483871 ]
#  [0.09574468 0.26595745 0.52659574 0.05851064 0.05319149]
#  [0.03092784 0.38659794 0.35051546 0.1443299  0.08762887]
#  [0.08717949 0.32307692 0.42051282 0.12820513 0.04102564]]
# A =  [[0.18393481 0.1443539  0.21885914 0.225844   0.22700815]]
# B =  [[0.07217695 0.3201397  0.43189756 0.112922   0.0628638 ]]
# level      topic  emotion_level
# 2     性价比              1
# 4      位置              1
# 7     性价比              1
# 9     性价比              1
# 11    性价比              1
# ..    ...            ...
# 796    服务              1
# ...
# A =  [[0.15662651 0.1124498  0.16064257 0.10441767 0.46586345]]
# B =  [[0.16064257 0.29317269 0.34538153 0.11646586 0.08433735]]
# level      topic  emotion_level
# 16     设施              1
# 18    性价比              1
# 22     服务              1
# 35     卫生              1
# 45     位置              1
# 47     服务              1
# 49    性价比              1
# 51     设施              1
# 54    性价比              1
# 62     服务              1
# 79     设施              1
# 83     服务              1
# 84    性价比              1
# 88    性价比              1
# 97     设施              1
# 111    设施              1
# 113    设施              1
# 125   性价比              1
# 136    服务              1
# 139   性价比              1
# 142    位置              1
# 145   性价比              1
# 146    设施              1
# 148    服务              1
# 156    服务              1
# 162    设施              1
# 163   性价比              1
# 166   性价比              1
# 167    卫生              1
# 171   性价比              1
# 183    设施              1
# 184   性价比              1
# 200    卫生              1
# 204    卫生              1
# 205    服务              1
# 218   性价比              1
# 219   性价比              1
# 223   性价比              1
# 227    服务              1
# 228    设施              1
# 229    设施              1
# 232    位置              1
# level      topic  emotion_level
# 3      卫生              2
# 6      卫生              2
# 7     性价比              2
# 8     性价比              2
# 11     位置              2
# 15     卫生              2
# 17     服务              2
# 34     位置              2
# 36     设施              2
# 39     位置              2
# 42     服务              2
# 50     服务              2
# 53     设施              2
# 57     服务              2
# 59     卫生              2
# 67    性价比              2
# 70     服务              2
# 71    性价比              2
# 74     设施              2
# 78     设施              2
# 91     卫生              2
# 93    性价比              2
# 94     卫生              2
# 95     服务              2
# 96    性价比              2
# 98    性价比              2
# 99     设施              2
# 100    位置              2
# 102    卫生              2
# 104    设施              2
# 112    卫生              2
# 116   性价比              2
# 120    设施              2
# 121    卫生              2
# 150    服务              2
# 154   性价比              2
# 155   性价比              2
# 164    设施              2
# 168   性价比              2
# 169    卫生              2
# 182    卫生              2
# 185    设施              2
# 186    服务              2
# 187    位置              2
# 192   性价比              2
# 193    位置              2
# 195    设施              2
# 197    卫生              2
# 199    服务              2
# 202   性价比              2
# 207    卫生              2
# 208    设施              2
# 210    卫生              2
# 213    位置              2
# 214    服务              2
# 216    卫生              2
# 226    服务              2
# 231    位置              2
# 234   性价比              2
# 237    卫生              2
# level      topic  emotion_level
# 5      服务              3
# 14     服务              3
# 23     服务              3
# 26     服务              3
# 27     服务              3
# ..    ...            ...
# 198    设施              3
# 215   性价比              3
# 224    位置              3
# 235    卫生              3
# 236    服务              3
#
# [69 rows x 2 columns]
# level      topic  emotion_level
# 2      位置              4
# 9     性价比              4
# 12     服务              4
# 13     卫生              4
# 19     服务              4
# 20    性价比              4
# 21     卫生              4
# 24     卫生              4
# 25     卫生              4
# 33     服务              4
# 41     设施              4
# 48     卫生              4
# 56     卫生              4
# 61     设施              4
# 64     服务              4
# 69     设施              4
# 75     位置              4
# 89     位置              4
# 105    卫生              4
# 106    服务              4
# 107    卫生              4
# 110    服务              4
# 117    设施              4
# 118    卫生              4
# 123    位置              4
# 132    服务              4
# 133    卫生              4
# 140    服务              4
# 165    卫生              4
# 173    服务              4
# 176    服务              4
# 189    设施              4
# 196   性价比              4
# 203   性价比              4
# 206   性价比              4
# 209    位置              4
# 211    卫生              4
# 217   性价比              4
# 220    设施              4
# 221    卫生              4
# 225    设施              4
# 238    卫生              4
# level      topic  emotion_level
# 0      服务              5
# 1     性价比              5
# 4      位置              5
# 10     卫生              5
# 30     卫生              5
# 32     卫生              5
# 40     卫生              5
# 43     卫生              5
# 52     服务              5
# 72     服务              5
# 82     卫生              5
# 101    设施              5
# 114    服务              5
# 122    卫生              5
# 126    卫生              5
# 130    设施              5
# 135    卫生              5
# 137    设施              5
# 144    设施              5
# 188    卫生              5
# 190    设施              5
# 201    服务              5
# 212    位置              5
# 222    设施              5
# 230    设施              5
# 233    卫生              5
# R =  [[0.15       0.18333333 0.41666667 0.16666667 0.08333333]
#  [0.13043478 0.34782609 0.2173913  0.2173913  0.08695652]
#  [0.25       0.25       0.18181818 0.15909091 0.15909091]
#  [0.07692308 0.30769231 0.13461538 0.26923077 0.21153846]
#  [0.25       0.23333333 0.4        0.1        0.01666667]]
# A =  [[0.25104603 0.09623431 0.18410042 0.21757322 0.25104603]]
# B =  [[0.17573222 0.25104603 0.28870293 0.17573222 0.10878661]]
# level      topic  emotion_level
# 14     服务              1
# 24     服务              1
# 27     设施              1
# 28    性价比              1
# 34     位置              1
# 35    性价比              1
# 36     设施              1
# 48     服务              1
# 50    性价比              1
# 85    性价比              1
# 88     服务              1
# 89    性价比              1
# 108    设施              1
# 109   性价比              1
# 142   性价比              1
# 143    服务              1
# 151    设施              1
# 165    服务              1
# 176    服务              1
# 186    服务              1
# 188    服务              1
# 194    设施              1
# 205    服务              1
# 206    位置              1
# 207    服务              1
# 213    卫生              1
# 220   性价比              1
# 226    服务              1
# 231    服务              1
# level      topic  emotion_level
# 2      设施              2
# 7     性价比              2
# 11     服务              2
# 13     服务              2
# 16     卫生              2
# 18    性价比              2
# 20     服务              2
# 21    性价比              2
# 26     设施              2
# 31     卫生              2
# 32     服务              2
# 33     服务              2
# 46    性价比              2
# 53     服务              2
# 54     服务              2
# 56     位置              2
# 65     卫生              2
# 69     服务              2
# 72     卫生              2
# 79     设施              2
# 82     卫生              2
# 91     位置              2
# 92     服务              2
# 95     设施              2
# 98    性价比              2
# 99     服务              2
# 102    服务              2
# 104    服务              2
# 111   性价比              2
# 116   性价比              2
# 122   性价比              2
# 123   性价比              2
# 125    设施              2
# 131    服务              2
# 133    服务              2
# 136    服务              2
# 139    位置              2
# 140    设施              2
# 144    服务              2
# 147    服务              2
# 148    服务              2
# 153    位置              2
# 155   性价比              2
# 156   性价比              2
# 161    服务              2
# 164    服务              2
# 168    服务              2
# 172    服务              2
# 173   性价比              2
# 174   性价比              2
# 177    位置              2
# 183    服务              2
# 185    服务              2
# 195    服务              2
# 201    服务              2
# 202   性价比              2
# 223   性价比              2
# 227    位置              2
# 229    卫生              2
# 230    服务              2
# level      topic  emotion_level
# 0      卫生              3
# 3      设施              3
# 4      设施              3
# 9     性价比              3
# 12    性价比              3
# ..    ...            ...
# 219   性价比              3
# 221    服务              3
# 222   性价比              3
# 225   性价比              3
# 228    位置              3
#
# [107 rows x 2 columns]
# level      topic  emotion_level
# 1      卫生              4
# 5      位置              4
# 6     性价比              4
# 10     服务              4
# 17    性价比              4
# 22    性价比              4
# 44     位置              4
# 62    性价比              4
# 66     服务              4
# 71     服务              4
# 76     服务              4
# 83     服务              4
# 94     卫生              4
# 101    位置              4
# 129    位置              4
# 130    位置              4
# 138    位置              4
# 145    服务              4
# 178    服务              4
# 187    卫生              4
# 192    卫生              4
# 193   性价比              4
# 196   性价比              4
# 203    服务              4
# 210    卫生              4
# 212    服务              4
# 224    服务              4
# level      topic  emotion_level
# 8      卫生              5
# 40    性价比              5
# 63     卫生              5
# 68     服务              5
# 96    性价比              5
# 200   性价比              5
# 215    位置              5
# 216    位置              5
# 218    服务              5
# R =  [[0.14285714 0.2967033  0.42857143 0.10989011 0.02197802]
#  [0.08       0.24       0.36       0.24       0.08      ]
#  [0.2173913  0.26086957 0.52173913 0.         0.        ]
#  [0.04       0.24       0.44       0.2        0.08      ]
#  [0.11764706 0.22058824 0.52941176 0.08823529 0.04411765]]
# A =  [[0.39224138 0.10775862 0.09913793 0.10775862 0.29310345]]
# B =  [[0.125      0.25862069 0.4612069  0.11637931 0.0387931 ]]
# level      topic  emotion_level
# 5     性价比              1
# 13    性价比              1
# 19    性价比              1
# 44    性价比              1
# 86     位置              1
# 87     卫生              1
# 88     服务              1
# 118    服务              1
# 123   性价比              1
# 130   性价比              1
# 137    服务              1
# 159    服务              1
# 165    服务              1
# 174    位置              1
# 175    服务              1
# 183    设施              1
# 191    服务              1
# 200    服务              1
# 209    服务              1
# 225    卫生              1
# level      topic  emotion_level
# 1     性价比              2
# 3     性价比              2
# 4      位置              2
# 7      卫生              2
# 18     位置              2
# ..    ...            ...
# 221    卫生              2
# 224    位置              2
# 229    设施              2
# 231    设施              2
# 232   性价比              2
#
# [69 rows x 2 columns]
# level      topic  emotion_level
# 2     性价比              3
# 8      位置              3
# 10     设施              3
# 15     服务              3
# 23     卫生              3
# ..    ...            ...
# 226    服务              3
# 227   性价比              3
# 228    卫生              3
# 233    卫生              3
# 234   性价比              3
#
# [85 rows x 2 columns]
# level      topic  emotion_level
# 6     性价比              4
# 11     卫生              4
# 12     卫生              4
# 14     服务              4
# 16    性价比              4
# 20     服务              4
# 22     设施              4
# 28    性价比              4
# 31    性价比              4
# 32     卫生              4
# 51    性价比              4
# 57    性价比              4
# 59     卫生              4
# 60     卫生              4
# 78     位置              4
# 80    性价比              4
# 83    性价比              4
# 91    性价比              4
# 92     卫生              4
# 97     服务              4
# 104   性价比              4
# 109    服务              4
# 117   性价比              4
# 125    设施              4
# 131    服务              4
# 139    位置              4
# 140    设施              4
# 147    卫生              4
# 156   性价比              4
# 160    卫生              4
# 171    服务              4
# 185    位置              4
# 213    位置              4
# 230   性价比              4
# level      topic  emotion_level
# 0      设施              5
# 9     性价比              5
# 17     位置              5
# 21     设施              5
# 35    性价比              5
# 39     位置              5
# 46     服务              5
# 48    性价比              5
# 52    性价比              5
# 61     位置              5
# 63     卫生              5
# 71     卫生              5
# 72     设施              5
# 76     卫生              5
# 77     服务              5
# 79    性价比              5
# 84     卫生              5
# 93     卫生              5
# 102   性价比              5
# 114    设施              5
# 126   性价比              5
# 127   性价比              5
# 133    服务              5
# 149   性价比              5
# 154    设施              5
# 178    设施              5
# 186    卫生              5
# R =  [[0.2        0.28888889 0.31111111 0.13333333 0.06666667]
#  [0.07407407 0.37037037 0.2962963  0.14814815 0.11111111]
#  [0.02272727 0.31818182 0.45454545 0.06818182 0.13636364]
#  [0.05405405 0.21621622 0.35135135 0.21621622 0.16216216]
#  [0.07317073 0.29268293 0.36585366 0.15853659 0.1097561 ]]
# A =  [[0.19148936 0.11489362 0.18723404 0.15744681 0.34893617]]
# B =  [[0.08510638 0.29361702 0.36170213 0.14468085 0.11489362]]
# level      topic  emotion_level
# 9      卫生              1
# 14    性价比              1
# 20     服务              1
# 22     位置              1
# 25    性价比              1
# 26    性价比              1
# 27     服务              1
# 28     服务              1
# 33    性价比              1
# 34    性价比              1
# 35     卫生              1
# 46     服务              1
# 62     服务              1
# 76     服务              1
# 109    服务              1
# 126    服务              1
# 136    设施              1
# 171   性价比              1
# 175   性价比              1
# 179    设施              1
# 181   性价比              1
# 184    服务              1
# 189    设施              1
# 195    位置              1
# 208    服务              1
# 213   性价比              1
# 225   性价比              1
# 228    服务              1
# 229    服务              1
# 230    设施              1
# level      topic  emotion_level
# 0      卫生              2
# 4      服务              2
# 7      位置              2
# 10     服务              2
# 11     位置              2
# ..    ...            ...
# 217    设施              2
# 218   性价比              2
# 219    卫生              2
# 222    服务              2
# 227    位置              2
#
# [70 rows x 2 columns]
# level      topic  emotion_level
# 5      服务              3
# 8      服务              3
# 12     卫生              3
# 15     设施              3
# 16     位置              3
# ..    ...            ...
# 221    卫生              3
# 223    设施              3
# 224    位置              3
# 226   性价比              3
# 232   性价比              3
#
# [71 rows x 2 columns]
# level      topic  emotion_level
# 1      服务              4
# 6      位置              4
# 13    性价比              4
# 24     卫生              4
# 30     服务              4
# 57     服务              4
# 59     服务              4
# 61    性价比              4
# 65     服务              4
# 70     位置              4
# 71     卫生              4
# 73     卫生              4
# 74     设施              4
# 91    性价比              4
# 92     服务              4
# 102   性价比              4
# 107    服务              4
# 111    卫生              4
# 113    卫生              4
# 115    卫生              4
# 123    设施              4
# 128    卫生              4
# 144    卫生              4
# 149    设施              4
# 153    设施              4
# 163    卫生              4
# 168    服务              4
# 182    卫生              4
# 183    服务              4
# 191    位置              4
# 198   性价比              4
# 199    位置              4
# 204   性价比              4
# 212    卫生              4
# 231    卫生              4
# level      topic  emotion_level
# 2      服务              5
# 3     性价比              5
# 18    性价比              5
# 32    性价比              5
# 38    性价比              5
# 44     服务              5
# 55     卫生              5
# 56    性价比              5
# 58     卫生              5
# 60    性价比              5
# 68     服务              5
# 69    性价比              5
# 77     卫生              5
# 81     服务              5
# 82     服务              5
# 83    性价比              5
# 89     设施              5
# 90    性价比              5
# 99     卫生              5
# 106    服务              5
# 108   性价比              5
# 127    服务              5
# 133   性价比              5
# 138    设施              5
# 151   性价比              5
# 192    卫生              5
# 215   性价比              5
# R =  [[0.19047619 0.22222222 0.33333333 0.14285714 0.11111111]
#  [0.0952381  0.47619048 0.23809524 0.19047619 0.        ]
#  [0.125      0.21875    0.46875    0.125      0.0625    ]
#  [0.03703704 0.42592593 0.22222222 0.22222222 0.09259259]
#  [0.15873016 0.25396825 0.28571429 0.0952381  0.20634921]]
# A =  [[0.27038627 0.09012876 0.13733906 0.23175966 0.27038627]]
# B =  [[0.12875536 0.30042918 0.30472103 0.15021459 0.11587983]]

# %%
rating
# Out:
#     序号 景区名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0    1   A1  3.3   3.3   3.1   3.4   2.8    3.4
# 1    2   A2  3.3   3.3   3.1   3.3   3.0    3.4
# 2    3   A3  2.7   2.9   2.5   3.0   2.1    2.8
# 3    4   A4  2.8   2.9   2.6   2.9   2.3    2.8
# 4    5   A5  3.0   2.9   2.9   3.1   2.7    3.1
# 5    6   A6  2.8   2.8   2.6   2.9   2.2    2.9
# 6    7   A7  3.4   3.4   3.4   3.5   3.1    3.4
# 7    8   A8  3.0   3.0   2.8   3.0   2.7    3.2
# 8    9   A9  3.3   3.4   3.2   3.5   3.1    3.3
# 9   10  A10  2.7   2.9   2.5   2.7   2.0    2.8
# 10  11  A11  3.3   3.3   3.3   3.4   3.2    3.5
# 11  12  A12  3.2   3.3   3.1   3.2   3.1    3.3
# 12  13  A13  3.2   3.1   3.2   3.3   3.2    3.4
# 13  14  A14  3.3   3.3   3.2   3.3   3.1    3.4
# 14  15  A15  3.3   3.4   3.2   3.3   3.1    3.5
# 15  16  A16  3.3   3.3   3.3   3.2   3.1    3.3
# 16  17  A17  3.3   3.3   3.2   3.4   3.1    3.5
# 17  18  A18  3.3   3.4   3.1   3.6   3.1    3.3
# 18  19  A19  3.3   3.3   3.2   3.4   3.2    3.6
# 19  20  A20  2.8   2.9   2.7   2.8   2.3    2.9
# 20  21  A21  3.2   3.2   3.2   3.3   3.1    3.3
# 21  22  A22  3.3   3.3   3.4   3.3   3.1    3.3
# 22  23  A23  3.2   3.3   3.1   3.4   2.9    3.5
# 23  24  A24  3.2   3.2   3.2   3.1   2.8    3.6
# 24  25  A25  3.2   3.1   3.1   3.1   3.0    3.4
# 25  26  A26  3.3   3.2   3.4   3.6   3.1    3.3
# 26  27  A27  3.2   3.3   3.1   3.2   3.0    3.4
# 27  28  A28  3.0   3.1   2.8   3.0   2.6    3.0
# 28  29  A29  3.3   3.4   3.3   3.3   3.0    3.5
# 29  30  A30  3.3   3.4   3.3   3.3   3.1    3.5
# 30  31  A31  2.6   2.8   2.5   2.8   2.1    2.7
# 31  32  A32  3.3   3.3   3.2   3.3   3.1    3.4
# 32  33  A33  3.3   3.3   3.2   3.3   3.3    3.4
# 33  34  A34  2.8   2.9   2.6   2.7   2.0    3.1
# 34  35  A35  3.3   3.3   3.2   3.1   3.2    3.4
# 35  36  A36  3.2   3.3   3.2   3.2   3.1    3.5
# 36  37  A37  3.2   3.1   3.3   3.3   2.7    3.4
# 37  38  A38  3.0   3.0   3.1   3.0   2.9    3.3
# 38  39  A39  3.3   3.4   3.4   3.2   3.1    3.5
# 39  40  A40  3.2   3.5   3.2   3.1   3.0    3.3
# 40  41  A41  3.0   3.0   2.9   3.1   2.7    3.2
# 41  42  A42  3.3   3.2   3.4   3.3   3.1    3.3
# 42  43  A43  3.1   3.1   3.0   3.0   3.1    3.3
# 43  44  A44  3.2   3.7   3.3   3.3   3.1    3.1
# 44  45  A45  3.3   3.8   3.1   3.3   2.8    3.4
# 45  46  A46  3.3   3.4   3.7   3.4   3.0    3.2
# 46  47  A47  3.2   3.2   3.2   3.3   2.8    3.6
# 47  48  A48  3.3   3.4   3.0   3.7   3.0    3.3
# 48  49  A49  3.1   3.4   3.1   3.0   2.8    3.1
# 49  50  A50  3.2   3.2   3.5   3.2   3.1    3.1

# %%
rating.to_csv(result_path_u, encoding='utf-8', index=False)
rating.to_csv(result_path_g, encoding='gbk' , index=False)
